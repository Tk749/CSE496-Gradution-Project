# %%
edges = [
    # From Başlangıç nodes
    ("Başlangıç1", "Ara10"),
    ("Başlangıç2", "Ara11"),
    ("Başlangıç3", "Ara13"),
    ("Başlangıç3", "Ara12"),
    ("Başlangıç3", "Başlangıç4"),
    ("Başlangıç4", "Başlangıç3"),
    ("Başlangıç4", "Başlangıç5"),
    ("Başlangıç5", "Ara13"),
    ("Başlangıç5", "Başlangıç4"),
    ("Başlangıç6", "Ara14"),
    ("Başlangıç6", "Başlangıç7"),
    ("Başlangıç7", "Başlangıç6"),
    ("Başlangıç8", "Ara21"),
    ("Başlangıç9", "Ara24"),

    # Intermediate connections
    ("Ara10", "Ara16"),
    ("Ara11", "Ara10"),
    ("Ara11", "Ara12"),
    ("Ara11", "Ara17"),
    ("Ara12", "Ara18"),
    ("Ara13", "Ara14"),
    ("Ara13", "Ara19"),
    ("Ara14", "Ara15"),
    ("Ara15", "Ara20"),
    ("Ara15", "Ara35"),
    ("Ara16", "Ara28"),
    ("Ara17", "Ara16"),
    ("Ara17", "Ara18"),
    ("Ara18", "Ara19"),
    ("Ara19", "Ara20"),
    ("Ara20", "Ara34"),
    ("Ara21", "Ara22"),
    ("Ara21", "Ara35"),
    ("Ara22", "Ara23"),
    ("Ara22", "Bit45"),
    ("Ara23", "Bit46"),
    ("Ara24", "Ara25"),
    ("Ara24", "Ara36"),
    ("Ara25", "Ara26"),
    ("Ara25", "Ara37"),
    ("Ara26", "Ara27"),
    ("Ara26", "Ara38"),
    ("Ara27", "Ara39"),
    ("Ara28", "Bit29"),
    ("Ara28", "Bit50"),
    ("Ara32", "Bit31"),
    ("Ara32", "Bit40"),
    ("Ara33", "Ara32"),
    ("Ara33", "Bit41"),
    ("Ara34", "Bit42"),
    ("Ara34", "Ara33"),
    ("Ara35", "Ara34"),
    ("Ara35", "Bit44"),
    ("Ara36", "Ara37"),
    ("Ara36", "Bit47"),
    ("Ara37", "Ara38"),
    ("Ara37", "Bit48"),
    ("Ara38", "Ara39"),
    ("Ara39", "Bit49"),
]

travel_time = {
    # From Başlangıç nodes
    ("Başlangıç1", "Ara10"): 32.4,
    ("Başlangıç2", "Ara11"): 18,
    ("Başlangıç3", "Ara13"): 21.6,
    ("Başlangıç3", "Ara12"): 19.8,
    ("Başlangıç3", "Başlangıç4"): 0,
    ("Başlangıç4", "Başlangıç3"): 0,
    ("Başlangıç4", "Başlangıç5"): 0,
    ("Başlangıç5", "Ara13"): 37.8,
    ("Başlangıç5", "Başlangıç4"): 0,
    ("Başlangıç6", "Ara14"): 27,
    ("Başlangıç6", "Başlangıç7"): 0,
    ("Başlangıç7", "Başlangıç6"): 0,
    ("Başlangıç8", "Ara21"): 63,
    ("Başlangıç9", "Ara24"): 34.2,

    # Intermediate connections
    ("Ara10", "Ara16"): 43.2,
    ("Ara11", "Ara10"): 77.4,
    ("Ara11", "Ara12"): 68,
    ("Ara11", "Ara17"): 18,
    ("Ara12", "Ara18"): 27,
    ("Ara13", "Ara14"): 54,
    ("Ara13", "Ara19"): 34.2,
    ("Ara14", "Ara15"): 10.8,
    ("Ara15", "Ara20"): 21.6,
    ("Ara15", "Ara35"): 55.8,
    ("Ara16", "Ara28"): 176.4,
    ("Ara17", "Ara16"): 14,
    ("Ara17", "Ara18"): 12,
    ("Ara18", "Ara19"): 27,
    ("Ara19", "Ara20"): 66.6,
    ("Ara20", "Ara34"): 46.8,
    ("Ara21", "Ara22"): 41.4,
    ("Ara21", "Ara35"): 18,
    ("Ara22", "Ara23"): 32.4,
    ("Ara22", "Bit45"): 81,
    ("Ara23", "Bit46"): 77.4,
    ("Ara24", "Ara25"): 21.6,
    ("Ara24", "Ara36"): 25.2,
    ("Ara25", "Ara26"): 52.2,
    ("Ara25", "Ara37"): 25.2,
    ("Ara26", "Ara27"): 48.6,
    ("Ara26", "Ara38"): 25.2,
    ("Ara27", "Ara39"): 28.8,
    ("Ara28", "Bit29"): 50.4,
    ("Ara28", "Bit50"): 45,
    ("Ara32", "Bit31"): 19.8,
    ("Ara32", "Bit40"): 27,
    ("Ara33", "Ara32"): 10.8,
    ("Ara33", "Bit41"): 32.4,
    ("Ara34", "Bit42"): 45,
    ("Ara34", "Ara33"): 63,
    ("Ara35", "Ara34"): 48.6,
    ("Ara35", "Bit44"): 100.8,
    ("Ara36", "Ara37"): 21.6,
    ("Ara36", "Bit47"): 70.2,
    ("Ara37", "Ara38"): 18,
    ("Ara37", "Bit48"): 25,
    ("Ara38", "Ara39"): 50.4,
    ("Ara39", "Bit49"): 52.2,
}

capacity = {
    # From Başlangıç nodes
    ("Başlangıç1", "Ara10"): 4400,
    ("Başlangıç2", "Ara11"): 2200,
    ("Başlangıç3", "Ara13"): 2200,
    ("Başlangıç3", "Ara12"): 6600,
    ("Başlangıç3", "Başlangıç4"): 100000,
    ("Başlangıç4", "Başlangıç3"): 100000,
    ("Başlangıç4", "Başlangıç5"): 100000,
    ("Başlangıç5", "Ara13"): 4400,
    ("Başlangıç5", "Başlangıç4"): 100000,
    ("Başlangıç6", "Ara14"): 6600,
    ("Başlangıç6", "Başlangıç7"): 100000,
    ("Başlangıç7", "Başlangıç6"): 100000,
    ("Başlangıç8", "Ara21"): 4400,
    ("Başlangıç9", "Ara24"): 6600,

    # Intermediate connections
    ("Ara10", "Ara16"): 4400,
    ("Ara11", "Ara10"): 4400,
    ("Ara11", "Ara12"): 4400,
    ("Ara11", "Ara17"): 2200,
    ("Ara12", "Ara18"): 2200,
    ("Ara13", "Ara14"): 6600,
    ("Ara13", "Ara19"): 4400,
    ("Ara14", "Ara15"): 8800,
    ("Ara15", "Ara20"): 4400,
    ("Ara15", "Ara35"): 6600,
    ("Ara16", "Ara28"): 6600,
    ("Ara17", "Ara16"): 4400,
    ("Ara17", "Ara18"): 6600,
    ("Ara18", "Ara19"): 6600,
    ("Ara19", "Ara20"): 6600,
    ("Ara20", "Ara34"): 8800,
    ("Ara21", "Ara22"): 6600,
    ("Ara21", "Ara35"): 4400,
    ("Ara22", "Ara23"): 6600,
    ("Ara22", "Bit45"): 2200,
    ("Ara23", "Bit46"): 4400,
    ("Ara24", "Ara25"): 2200,
    ("Ara24", "Ara36"): 6600,
    ("Ara25", "Ara26"): 4400,
    ("Ara25", "Ara37"): 6600,
    ("Ara26", "Ara27"): 4400,
    ("Ara26", "Ara38"): 4400,
    ("Ara27", "Ara39"): 4400,
    ("Ara28", "Bit29"): 4400,
    ("Ara28", "Bit50"): 4400,
    ("Ara32", "Bit31"): 2200,
    ("Ara32", "Bit40"): 2200,
    ("Ara33", "Ara32"): 4400,
    ("Ara33", "Bit41"): 2200,
    ("Ara34", "Bit42"): 4400,
    ("Ara34", "Ara33"): 6600,
    ("Ara35", "Ara34"): 6600,
    ("Ara35", "Bit44"): 6600,
    ("Ara36", "Ara37"): 6600,
    ("Ara36", "Bit47"): 2200,
    ("Ara37", "Ara38"): 2200,
    ("Ara37", "Bit48"): 2200,
    ("Ara38", "Ara39"): 2200,
    ("Ara39", "Bit49"): 4400,
}

passengers = {
    "Başlangıç1": 2000,
    "Başlangıç2": 1000,
    "Başlangıç3": 2200,
    "Başlangıç4": 0,
    "Başlangıç5": 2800,
    "Başlangıç6": 3000,
    "Başlangıç7": 0,
    "Başlangıç8": 2000,
    "Başlangıç9": 3000,

    "Ara10": 0, "Ara11": 0, "Ara12": 0, "Ara13": 0, "Ara14": 0,
    "Ara15": 0, "Ara16": 0, "Ara17": 0, "Ara18": 0, "Ara19": 0,
    "Ara20": 0, "Ara21": 0, "Ara22": 0, "Ara23": 0, "Ara24": 0,
    "Ara25": 0, "Ara26": 0, "Ara27": 0, "Ara28": 0, "Bit29": 0,
    "Bit30": 0, "Bit31": 0, "Ara32": 0, "Ara33": 0, "Ara34": 0,
    "Ara35": 0, "Ara36": 0, "Ara37": 0, "Ara38": 0, "Ara39": 0,
    "Bit40": 0, "Bit41": 0, "Bit42": 0, "Bit43": 0, "Bit44": 0,
    "Bit45": 0, "Bit46": 0, "Bit47": 0, "Bit48": 0, "Bit49": 0,
    "Bit50": 0
}

# %%
import pyomo.environ as pyo
import networkx as nx
import matplotlib.pyplot as plt
from itertools import islice

def k_shortest_paths(G, source, target, k):
    """
    İki düğüm arasındaki en kısa k adet yolu bulur
    """
    return list(islice(nx.shortest_simple_paths(G, source, target), k))

def create_graph(edges, capacity):
    """
    Verilen kenarlardan yönlü graf oluşturur
    """
    G = nx.DiGraph()
    for (i,j) in edges:
        G.add_edge(i, j, capacity=capacity[(i,j)])
    return G


def create_evacuation_model(edges, passengers, capacity, base_travel_time, K=50):
    """
    Tahliye optimizasyon modelini oluşturur
    """
    # Graf oluştur
    G = create_graph(edges, capacity)
    
    # Model oluştur
    model = pyo.ConcreteModel()
    
    # Düğüm kümeleri
    all_nodes = set([i for (i,j) in edges] + [j for (i,j) in edges])
    baslangic_nodes = sorted(set(n for n in all_nodes if n.startswith('Başlangıç')))
    bitis_nodes = sorted(set(n for n in all_nodes if n.startswith('Bit')))
    
    # Kümeler
    model.edges = pyo.Set(initialize=edges)
    model.baslangic_nodes = pyo.Set(initialize=baslangic_nodes)
    model.bitis_nodes = pyo.Set(initialize=bitis_nodes)
    
    # K en kısa yolları bul
    paths = {}
    for s in baslangic_nodes:
        for t in bitis_nodes:
            try:
                paths[(s,t)] = k_shortest_paths(G, s, t, K)
            except:
                continue
    
    # Yol kümesi
    model.paths = pyo.Set(initialize=[(s,t,k) for (s,t) in paths.keys() 
                                    for k in range(len(paths[(s,t)]))])
    
    # Değişkenler
    model.edge_flow = pyo.Var(model.edges, domain=pyo.NonNegativeIntegers)
    model.path_flow = pyo.Var(model.paths, domain=pyo.NonNegativeIntegers)
    model.travel_time = pyo.Var(model.edges, domain=pyo.NonNegativeReals)
    
    # Amaç fonksiyonu
    def objective_rule(model):
        return sum(model.edge_flow[e] * model.travel_time[e] for e in model.edges)
    model.objective = pyo.Objective(rule=objective_rule, sense=pyo.minimize)
    
    # Kısıtlar
    def demand_rule(model, s):
        return sum(model.path_flow[s,t,k] for t in model.bitis_nodes 
                  for k in range(len(paths.get((s,t), [])))
                  if (s,t,k) in model.paths) == passengers[s]
    model.demand = pyo.Constraint(model.baslangic_nodes, rule=demand_rule)
    
    def capacity_rule(model, i, j):
        return model.edge_flow[i,j] <= capacity[(i,j)]
    model.capacity = pyo.Constraint(model.edges, rule=capacity_rule)
    
    def flow_conservation(model, i, j):
        edge_flow = model.edge_flow[i,j]
        path_sum = sum(model.path_flow[s,t,k] 
                      for (s,t,k) in model.paths 
                      if (i,j) in zip(paths[(s,t)][k][:-1], paths[(s,t)][k][1:]))
        return edge_flow == path_sum
    model.flow_conservation = pyo.Constraint(model.edges, rule=flow_conservation)
    
    def travel_time_rule(model, i, j):
        return model.travel_time[i,j] == base_travel_time[(i,j)] * \
               (1 + 2 * (model.edge_flow[i,j]/capacity[(i,j)])**2)
    model.travel_time_constraint = pyo.Constraint(model.edges, rule=travel_time_rule)
    
    return model, paths, G

def solve_model(model, base_time_dict, cap_dict):
    """
    NLP modelini çözer ve tam sayı sonuçlar üretir.
    Ayrıca seyahat sürelerini güncellemek için verilen sözlükleri kullanır.
    """
    solver = pyo.SolverFactory('ipopt')
    solver.options['max_iter'] = 5000
    solver.options['tol'] = 1e-6


    # İlk çözüm
    results = solver.solve(model, tee=True)

    # Flow değerlerini tam sayıya yuvarla
    for edge in model.edges:
        current_flow = pyo.value(model.edge_flow[edge])
        model.edge_flow[edge].set_value(round(current_flow))

    for path in model.paths:
        current_flow = pyo.value(model.path_flow[path])
        model.path_flow[path].set_value(round(current_flow))

    # Travel time'ları güncelle
    for i,j in model.edges:
        current_flow = pyo.value(model.edge_flow[i,j])
        base_time = base_time_dict[(i,j)]
        cap = cap_dict[(i,j)]
        new_time = base_time * (1 + 2 * (current_flow/cap)**2)
        model.travel_time[i,j].set_value(new_time)

    return results

# %%
import random
import numpy as np

def print_results(model, edges, capacity, G, paths):
    """
    Display and visualize the results.
    """
    print("\n==================== RESULTS ====================")
    print(f"Objective Value: {pyo.value(model.objective):.2f}")
    
    # Print Edge Flow Table
    print("\nEDGE FLOWS AND TRAVEL TIMES:")
    print("-" * 60)
    print(f"{'Edge':<20} {'Flow':<10} {'Travel Time':<15} {'Capacity Usage':<15}")
    print("-" * 60)
    
    flow_values = {}
    total_flow = 0
    total_travel_time = 0
    total_capacity_usage = 0
    
    for (i, j) in edges:
        flow = int(round(pyo.value(model.edge_flow[i, j])))
        flow_values[(i, j)] = flow
        total_flow += flow
        time = pyo.value(model.travel_time[i, j])
        total_travel_time += time
        capacity_usage = (flow / capacity[(i, j)]) * 100
        total_capacity_usage += capacity_usage
        
        print(f"{i} -> {j:<15} {flow:<10} {time:<15.2f} {capacity_usage:<15.1f}")
    
    print("-" * 60)
    
    print("\nPATH FLOWS:")
    print("-" * 80)
    print(f"{'Source':<15} {'Target':<15} {'Path #':<5} {'Flow':>10} {'Time':>10}")
    print("-" * 80)
    
    path_times = []
    path_flow_weighted_times = []
    total_path_flows = []
    
    for s in model.baslangic_nodes:
        for t in model.bitis_nodes:
            for k in range(len(paths.get((s, t), []))):
                if (s, t, k) in model.path_flow:
                    flow = int(round(pyo.value(model.path_flow[s, t, k])))
                    if flow > 0:
                        total_path_flows.append(flow)
                        path = paths[(s, t)][k]
                        total_time = 0
                        individual_times = []
                        
                        for i in range(len(path) - 1):
                            edge = (path[i], path[i + 1])
                            edge_time = pyo.value(model.travel_time[edge])
                            total_time += edge_time
                            individual_times.append(edge_time)
                        
                        # Append path time and weighted flow*time for later calculations
                        path_times.append(total_time)
                        path_flow_weighted_times.append(flow * total_time)
                        
                        print(f"{s:<15} {t:<15} {k + 1:>5} {flow:>10} {total_time:>10.2f}")
                        print(f"    Path: {' -> '.join(path)}")
    
    if total_path_flows:
        max_path_time = max(path_times) if path_times else 0
        min_path_time = min(path_times) if path_times else 0
        total_path_flow = sum(total_path_flows)
        weighted_avg_time = (
            sum(path_flow_weighted_times) / total_path_flow if total_path_flow > 0 else 0
        )
        
        print("\nPATH TIME SUMMARY:")
        print(f"Minimum Path Time: {min_path_time:.2f}")
        print(f"Maximum Path Time: {max_path_time:.2f}")
        print(f"Flow-Weighted Average Path Time: {weighted_avg_time:.2f}")


def print_passenger_distribution(passengers):
    print("\n========= BAŞLANGIÇ NOKTALARI YOLCU DAĞILIMI =========")
    print("-" * 50)
    print(f"{'Başlangıç Noktası':<20} {'Yolcu Sayısı':>15}")
    print("-" * 50) 
    
    toplam_yolcu = 0
    for node, count in passengers.items():
        if node.startswith('Başlangıç') and count > 0:
            print(f"{node:<20} {count:>15,}")
            toplam_yolcu += count
    
    print("-" * 50)
    print(f"{'TOPLAM':<20} {toplam_yolcu:>15,}")
    print("-" * 50)
    
    return toplam_yolcu

def analyze_model(model, edges, capacity, stage_label):
    print(f"\n===== {stage_label} ANAL\u0130Z\u0130 =====")
    
    # Toplam ak\u0131\u015f miktar\u0131
    total_flow = sum(pyo.value(model.edge_flow[e]) for e in edges)
    
    # Ortalama seyahat süresi
    avg_travel_time = sum(pyo.value(model.travel_time[e]) for e in edges) / len(edges)
    
    # Kapasite kullanım oranları
    max_utilization = 0
    most_congested_edge = None
    utilizations = []
    
    # Toplam seyahat süreleri hesaplama
    total_travel_time = 0
    edge_travel_times = {}
    
    for e in edges:
        flow = pyo.value(model.edge_flow[e])
        travel_time = pyo.value(model.travel_time[e])
        cap = capacity[e]
        util = flow / cap if cap > 0 else 0
        utilizations.append(util)

        if util > max_utilization:
            max_utilization = util
            most_congested_edge = e
        
        # Her bir kenarın toplam seyahat süresi
        edge_total_time = flow * travel_time
        edge_travel_times[e] = edge_total_time
        total_travel_time += edge_total_time

    # Sonuçları ekrana yazdırma
    print(f"Toplam Akış Miktarı: {total_flow}")
    print(f"Ortalama Seyahat Süresi: {avg_travel_time:.2f}")
    print(f"En Yüksek Kapasite Kullanımı: {max_utilization*100:.1f}% (Kenar: {most_congested_edge})")
    print(f"Tüm Kenarlar İçin Toplam Seyahat Süresi: {total_travel_time:.2f}")

    print("\nHer Kenarın Toplam Seyahat Süreleri:")
    for e, time in edge_travel_times.items():
        print(f"  Kenar {e}: {time:.2f}")
    
    # Kapasite kullanım oranlarının histogramını oluşturma
    import matplotlib.pyplot as plt
    plt.figure(figsize=(10, 6))
    plt.hist(utilizations, bins=20, color='blue', alpha=0.7)
    plt.title(f"{stage_label} - Kapasite Kullanım Dağılımı")
    plt.xlabel("Kapasite Kullanım Oranı")
    plt.ylabel("Kenar Sayısı")
    plt.grid(True)
    plt.show()

# %%
def visualize_single_stage(model, edges, capacity, G, stage_label="Stage Visualization"):
    """
    Tek bir aşamanın ağını görselleştirir.
    Kenar renkleri kapasite kullanımına göre belirlenir.
    Düğümler başlangıç, bitiş ve ara düğümler olarak hizalanır.
    """
    fig, ax = plt.subplots(figsize=(10, 10))
    
    # Genel konumlandırma için spring layout
    pos = nx.spring_layout(G, seed=42)
    
    # Düğümleri kategorilere ayır
    start_nodes = sorted([n for n in G.nodes() if n.startswith('Başlangıç')])
    finish_nodes = sorted([n for n in G.nodes() if n.startswith('Bit')])
    other_nodes = sorted(set(G.nodes()) - set(start_nodes) - set(finish_nodes))
    
    # Başlangıç düğümlerini hizalama (sol taraf)
    for i, node in enumerate(start_nodes):
        y = 1 - 2*i/(len(start_nodes)-1) if len(start_nodes)>1 else 0
        pos[node] = (-1, y)
    
    # Bitiş düğümlerini hizalama (sağ taraf)
    for i, node in enumerate(finish_nodes):
        y = 1 - 2*i/(len(finish_nodes)-1) if len(finish_nodes)>1 else 0
        pos[node] = (1, y)
    
    # Ara düğümleri hizalama (orta), bağlantılarına bağlı olarak sola/sağa kaydırma
    for i, node in enumerate(other_nodes):
        y = 1 - 2*i/(len(other_nodes)-1) if len(other_nodes)>1 else 0
        
        # Ara düğümün bağlantılarına göre x konumu hesaplama
        x_positions = []
        # Gelen kenarlar için (bu düğüm hedefse) sola kaydır
        for predecessor in G.predecessors(node):
            if predecessor in other_nodes:
                x_positions.append(-0.5)
        # Giden kenarlar için (bu düğüm kaynaksa) sağa kaydır
        for successor in G.successors(node):
            if successor in other_nodes:
                x_positions.append(0.5)
        
        # Eğer bağlantı yoksa x = 0, aksi halde ortalama al
        x = sum(x_positions)/len(x_positions) if x_positions else 0
        pos[node] = (x, y)
    
    # Düğümleri çiz
    nx.draw_networkx_nodes(G, pos, ax=ax, node_size=300, node_color='lightblue')
    nx.draw_networkx_labels(G, pos, ax=ax, font_size=8)
    
    # Kenar renklerini akışa göre belirle
    edge_colors = []
    for (u, v) in G.edges():
        try:
            flow = pyo.value(model.edge_flow[u, v])
        except KeyError:
            flow = 0
        ratio = flow / capacity[(u, v)] if capacity[(u, v)] > 0 else 0
        
        if ratio <= 0.25:
            edge_colors.append('green')
        elif ratio <= 0.5:
            edge_colors.append('yellow')
        elif ratio <= 0.75:
            edge_colors.append('orange')
        else:
            edge_colors.append('red')
    
    nx.draw_networkx_edges(G, pos, ax=ax, edge_color=edge_colors, arrowsize=10)
    
    ax.set_title(stage_label)
    ax.axis('off')
    plt.show()

# %%
def run_single_phase_optimization():
    # TEK FAZ - AŞAMA 1'e odaklanma
    print("SINGLE PHASE OPTIMIZATION")
    print("-------------------------")
    
    # Mevcut yolcu dağılımını yazdır ve toplam yolcu sayısını al
    toplam_yolcu = print_passenger_distribution(passengers)
    
    # Modeli oluşturma
    model, paths, G = create_evacuation_model(edges, passengers, capacity, travel_time)
    
    # Modeli çözme
    results = solve_model(model, travel_time, capacity)
    if results:
        print_results(model, edges, capacity, G, paths)
        analyze_model(model, edges, capacity, "Single Phase")
    
    # Optimizasyon sonuçlarını görselleştirme (İhtiyaca göre)
    if results:
        visualize_single_stage(model, edges, capacity, G, stage_label="Stage 1 Visualization")

# Modeli çalıştır
# if __name__ == "__main__":
#     run_single_phase_optimization()

# %% [markdown]
# ## Test case 4

# %%
edges = [
    # From Başlangıç nodes
    ("Başlangıç1", "Bit1"),
    ("Başlangıç1", "Bit2"),
    ("Başlangıç1", "Bit3"),
]

capacity = {
    # From Başlangıç nodes
    ("Başlangıç1", "Bit1"):1000,
    ("Başlangıç1", "Bit2"):1000,
    ("Başlangıç1", "Bit3"):1000
}

travel_time = {
    # From Başlangıç nodes
    ("Başlangıç1", "Bit1"):50,
    ("Başlangıç1", "Bit2"):50,
    ("Başlangıç1", "Bit3"):50,
}

passengers = {
    "Başlangıç1": 1500,
}

# %%
run_single_phase_optimization()
# Out:
# SINGLE PHASE OPTIMIZATION
# -------------------------
#
# ========= BAŞLANGIÇ NOKTALARI YOLCU DAĞILIMI =========
# --------------------------------------------------
# Başlangıç Noktası       Yolcu Sayısı
# --------------------------------------------------
# Başlangıç1                     1,500
# --------------------------------------------------
# TOPLAM                         1,500
# --------------------------------------------------
# Ipopt 3.14.17: max_iter=5000
# tol=1e-06
# output_file=ipopt_log.txt
#
# ==> Warning: Treating 0 binary and 6 integer variables as continuous.
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.17, running with linear solver MUMPS 5.7.3.
#
# Number of nonzeros in equality constraint Jacobian...:       15
# Number of nonzeros in inequality constraint Jacobian.:        3
# Number of nonzeros in Lagrangian Hessian.............:        6
#
# Total number of variables............................:        9
#                      variables with only lower bounds:        9
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:        3
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        3
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.9999940e-04 1.50e+03 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.5001500e+04 2.50e+01 5.00e+04  -1.0 5.00e+02    -  1.98e-05 1.00e+00h  1
#    2  1.1250000e+05 1.42e-14 4.58e-01  -1.0 2.50e+01    -  6.61e-01 1.00e+00h  1
#    3  1.1250000e+05 7.11e-15 3.19e-03  -1.0 2.41e-13    -  9.91e-01 1.00e+00   0
#    4  1.1250000e+05 0.00e+00 1.00e-06  -1.0 4.70e-14    -  1.00e+00 1.00e+00   0
#    5  1.1250000e+05 0.00e+00 2.83e-08  -2.5 9.25e-19    -  1.00e+00 1.00e+00T  0
#    6  1.1250000e+05 0.00e+00 1.50e-09  -3.8 8.44e-22    -  1.00e+00 1.00e+00T  0
#    7  1.1250000e+05 0.00e+00 1.85e-11  -5.7 1.07e-22    -  1.00e+00 1.00e+00T  0
#    8  1.1250000e+05 0.00e+00 9.14e-13  -7.0 6.25e-25    -  1.00e+00 1.00e+00T  0
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.1250000000000000e+05    1.1250000000000000e+05
# Dual infeasibility......:   9.1400129002392341e-13    9.1400129002392341e-13
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0909090909090901e-08    9.0909090909090901e-08
# Overall NLP error.......:   9.0909090909090901e-08    9.0909090909090901e-08
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 9
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 9
# Number of Lagrangian Hessian evaluations             = 8
# Total seconds in IPOPT                               = 0.025
#
# EXIT: Optimal Solution Found.
#
# ==================== RESULTS ====================
# Objective Value: 112500.00
#
# EDGE FLOWS AND TRAVEL TIMES:
# ------------------------------------------------------------
# Edge                 Flow       Travel Time     Capacity Usage
# ------------------------------------------------------------
# Başlangıç1 -> Bit1            500        75.00           50.0
# Başlangıç1 -> Bit2            500        75.00           50.0
# Başlangıç1 -> Bit3            500        75.00           50.0
# ------------------------------------------------------------
#
# PATH FLOWS:
# --------------------------------------------------------------------------------
# Source          Target          Path #       Flow       Time
# --------------------------------------------------------------------------------
# Başlangıç1      Bit1                1        500      75.00
#     Path: Başlangıç1 -> Bit1
# Başlangıç1      Bit2                1        500      75.00
#     Path: Başlangıç1 -> Bit2
# Başlangıç1      Bit3                1        500      75.00
#     Path: Başlangıç1 -> Bit3
#
# PATH TIME SUMMARY:
# Minimum Path Time: 75.00
# Maximum Path Time: 75.00
# Flow-Weighted Average Path Time: 75.00
#
# ===== Single Phase ANALİZİ =====
# Toplam Akış Miktarı: 1500
# Ortalama Seyahat Süresi: 75.00
# En Yüksek Kapasite Kullanımı: 50.0% (Kenar: ('Başlangıç1', 'Bit1'))
# Tüm Kenarlar İçin Toplam Seyahat Süresi: 112500.00

# %%
edges = [
    # From Başlangıç nodes
    ("Başlangıç1", "Bit1"),
    ("Başlangıç1", "Bit2"),
    ("Başlangıç1", "Bit3"),
]

capacity = {
    # From Başlangıç nodes
    ("Başlangıç1", "Bit1"):1000,
    ("Başlangıç1", "Bit2"):1000,
    ("Başlangıç1", "Bit3"):1000
}

travel_time = {
    # From Başlangıç nodes
    ("Başlangıç1", "Bit1"):40,
    ("Başlangıç1", "Bit2"):50,
    ("Başlangıç1", "Bit3"):60,
}

passengers = {
    "Başlangıç1": 1500,
}

# %%
run_single_phase_optimization()
# Out:
# SINGLE PHASE OPTIMIZATION
# -------------------------
#
# ========= BAŞLANGIÇ NOKTALARI YOLCU DAĞILIMI =========
# --------------------------------------------------
# Başlangıç Noktası       Yolcu Sayısı
# --------------------------------------------------
# Başlangıç1                     1,500
# --------------------------------------------------
# TOPLAM                         1,500
# --------------------------------------------------
# Ipopt 3.14.17: max_iter=5000
# tol=1e-06
# output_file=ipopt_log.txt
#
# ==> Warning: Treating 0 binary and 6 integer variables as continuous.
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.17, running with linear solver MUMPS 5.7.3.
#
# Number of nonzeros in equality constraint Jacobian...:       15
# Number of nonzeros in inequality constraint Jacobian.:        3
# Number of nonzeros in Lagrangian Hessian.............:        6
#
# Total number of variables............................:        9
#                      variables with only lower bounds:        9
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:        3
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        3
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.9999940e-04 1.50e+03 1.32e-07  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.5000501e+04 3.00e+01 5.00e+04  -1.0 5.00e+02    -  1.98e-05 1.00e+00h  1
#    2  1.1160170e+05 3.77e-02 2.47e+01  -1.0 2.79e+01    -  6.43e-01 1.00e+00h  1
#    3  1.0997574e+05 4.66e-01 9.37e-01  -1.0 6.71e+01    -  8.84e-01 1.00e+00f  1
#    4  1.1038263e+05 7.60e-04 1.52e-03  -1.0 2.76e+00    -  9.91e-01 1.00e+00h  1
#    5  1.1038324e+05 1.17e-09 2.00e-07  -1.7 3.82e-03    -  1.00e+00 1.00e+00h  1
#    6  1.1038324e+05 4.83e-13 1.51e-09  -3.8 6.84e-05    -  1.00e+00 1.00e+00h  1
#    7  1.1038324e+05 0.00e+00 1.85e-11  -5.7 5.12e-07    -  1.00e+00 1.00e+00h  1
#    8  1.1038324e+05 7.11e-15 9.22e-13  -7.0 6.04e-09    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.1038324435593058e+05    1.1038324435593058e+05
# Dual infeasibility......:   9.2240260926800873e-13    9.2240260926800873e-13
# Constraint violation....:   7.1054273576010019e-15    7.1054273576010019e-15
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0909090934824781e-08    9.0909090934824781e-08
# Overall NLP error.......:   9.0909090934824781e-08    9.0909090934824781e-08
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 9
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 9
# Number of Lagrangian Hessian evaluations             = 8
# Total seconds in IPOPT                               = 0.032
#
# EXIT: Optimal Solution Found.
#
# ==================== RESULTS ====================
# Objective Value: 110260.27
#
# EDGE FLOWS AND TRAVEL TIMES:
# ------------------------------------------------------------
# Edge                 Flow       Travel Time     Capacity Usage
# ------------------------------------------------------------
# Başlangıç1 -> Bit1            588        67.66           58.8
# Başlangıç1 -> Bit2            493        74.30           49.3
# Başlangıç1 -> Bit3            418        80.97           41.8
# ------------------------------------------------------------
#
# PATH FLOWS:
# --------------------------------------------------------------------------------
# Source          Target          Path #       Flow       Time
# --------------------------------------------------------------------------------
# Başlangıç1      Bit1                1        588      67.66
#     Path: Başlangıç1 -> Bit1
# Başlangıç1      Bit2                1        493      74.30
#     Path: Başlangıç1 -> Bit2
# Başlangıç1      Bit3                1        418      80.97
#     Path: Başlangıç1 -> Bit3
#
# PATH TIME SUMMARY:
# Minimum Path Time: 67.66
# Maximum Path Time: 80.97
# Flow-Weighted Average Path Time: 73.56
#
# ===== Single Phase ANALİZİ =====
# Toplam Akış Miktarı: 1499
# Ortalama Seyahat Süresi: 74.31
# En Yüksek Kapasite Kullanımı: 58.8% (Kenar: ('Başlangıç1', 'Bit1'))
# Tüm Kenarlar İçin Toplam Seyahat Süresi: 110260.27

# %%
edges = [
    # From Başlangıç nodes
    ("Başlangıç1", "Bit1"),
    ("Başlangıç1", "Bit2"),
    ("Başlangıç1", "Bit3"),
]

capacity = {
    # From Başlangıç nodes
    ("Başlangıç1", "Bit1"):1000,
    ("Başlangıç1", "Bit2"):1000,
    ("Başlangıç1", "Bit3"):1000
}

travel_time = {
    # From Başlangıç nodes
    ("Başlangıç1", "Bit1"):40,
    ("Başlangıç1", "Bit2"):50,
    ("Başlangıç1", "Bit3"):60,
}

passengers = {
    "Başlangıç1": 3001,
}

# %%
run_single_phase_optimization()
# Out:
# SINGLE PHASE OPTIMIZATION
# -------------------------
#
# ========= BAŞLANGIÇ NOKTALARI YOLCU DAĞILIMI =========
# --------------------------------------------------
# Başlangıç Noktası       Yolcu Sayısı
# --------------------------------------------------
# Başlangıç1                     3,001
# --------------------------------------------------
# TOPLAM                         3,001
# --------------------------------------------------
# Ipopt 3.14.17: max_iter=5000
# tol=1e-06
# output_file=ipopt_log.txt
#
# ==> Warning: Treating 0 binary and 6 integer variables as continuous.
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.17, running with linear solver MUMPS 5.7.3.
#
# Number of nonzeros in equality constraint Jacobian...:       15
# Number of nonzeros in inequality constraint Jacobian.:        3
# Number of nonzeros in Lagrangian Hessian.............:        6
#
# Total number of variables............................:        9
#                      variables with only lower bounds:        9
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        7
# Total number of inequality constraints...............:        3
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        3
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.9999940e-04 3.00e+03 1.32e-07  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.4695660e+05 1.18e+02 9.90e+04  -1.0 1.00e+03    -  9.90e-06 9.90e-01h  1
#    2  1.9649153e+05 9.84e+01 8.24e+04  -1.0 1.11e+02    -  2.52e-01 1.67e-01h  1
#    3  2.0177861e+05 9.64e+01 8.07e+04  -1.0 9.61e+01    -  4.25e-01 2.11e-02h  1
#    4  2.6989229e+05 6.96e+01 5.83e+04  -1.0 9.47e+01    -  4.73e-01 2.77e-01h  1
#    5  2.7746333e+05 6.67e+01 5.59e+04  -1.0 7.35e+01    -  1.00e+00 4.23e-02h  1
#    6  4.3881889e+05 4.46e+00 3.71e+03  -1.0 7.09e+01    -  1.00e+00 9.34e-01h  1
#    7  4.4044827e+05 3.84e+00 3.19e+03  -1.0 4.74e+00    -  1.00e+00 1.41e-01h  1
#    8  4.4046474e+05 3.83e+00 3.18e+03  -1.0 4.07e+00    -  1.00e+00 1.65e-03h  1
#    9  4.4048035e+05 3.82e+00 3.14e+05  -1.0 3.83e+00    -  1.00e+00 1.58e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.4048309e+05 3.82e+00 1.12e+09  -1.0 3.82e+00    -  1.00e+00 2.79e-04h  1
#   11r 4.4048309e+05 3.82e+00 1.00e+03   0.6 0.00e+00    -  0.00e+00 3.52e-07R  4
#   12r 4.4852181e+05 1.00e+00 9.95e+02   0.6 3.82e+03    -  9.94e-01 9.91e-04f  1
#   13  4.4852183e+05 1.00e+00 9.00e+04  -1.0 9.32e-01    -  9.83e-01 1.37e-05h  1
#   14r 4.4852183e+05 1.00e+00 1.00e+03  -0.0 0.00e+00    -  0.00e+00 2.71e-07R  2
#   15r 4.4975658e+05 1.00e+00 9.99e+02  -0.0 7.59e+02    -  1.52e-01 1.14e-03f  1
#   16r 4.4999341e+05 9.99e-01 8.46e+02  -0.0 1.31e+00    -  9.91e-01 1.52e-01f  1
#   17r 4.5012366e+05 2.91e-01 1.01e-05  -0.0 7.08e-01    -  1.00e+00 1.00e+00f  1
#   18  4.5012419e+05 2.90e-01 9.98e+02  -1.0 4.04e-01    -  9.90e-01 2.45e-03h  1
#   19  4.5012433e+05 2.90e-01 7.02e+05  -1.0 6.89e-01    -  9.99e-01 5.08e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  4.5012434e+05 2.90e-01 1.88e+10  -1.0 8.26e-01    -  1.00e+00 3.70e-05h  1
#   21r 4.5012434e+05 2.90e-01 1.00e+03  -0.5 0.00e+00    -  0.00e+00 1.95e-07R  2
#   22r 4.5016087e+05 1.53e-01 2.91e-06  -0.5 2.10e-01    -  1.00e+00 1.00e+00f  1
#   23r 4.5016097e+05 1.53e-01 2.08e-07  -2.9 3.41e-04    -  1.00e+00 1.00e+00f  1
#   24r 4.5016097e+05 1.53e-01 9.99e+02  -0.8 0.00e+00    -  0.00e+00 2.80e-07R  4
#   25r 4.5016062e+05 1.53e-01 9.96e+02  -0.8 1.53e-01    -  9.90e-01 3.91e-03f  9
#   26r 4.5014059e+05 1.96e-01 1.53e-06  -0.8 1.16e-01    -  1.00e+00 1.00e+00f  1
#   27r 4.5014072e+05 1.96e-01 7.57e-08  -3.4 3.30e-04    -  1.00e+00 1.00e+00f  1
#   28r 4.5014085e+05 1.95e-01 3.55e-09  -5.1 7.66e-04    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 28
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.5014095947545470e+05    4.5014095947545470e+05
# Dual infeasibility......:   1.0001342319284884e+03    1.0001342319284884e+03
# Constraint violation....:   1.9474615558874575e-01    1.9474615558874575e-01
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0949470119436053e-08    9.0949470119436053e-08
# Overall NLP error.......:   2.2002953116414722e+02    1.0001342319284884e+03
#
#
# Number of objective function evaluations             = 52
# Number of objective gradient evaluations             = 23
# Number of equality constraint evaluations            = 52
# Number of inequality constraint evaluations          = 52
# Number of equality constraint Jacobian evaluations   = 34
# Number of inequality constraint Jacobian evaluations = 34
# Number of Lagrangian Hessian evaluations             = 29
# Total seconds in IPOPT                               = 0.050
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: Ipopt 3.14.17\x3a Converged to a locally infeasible
#       point. Problem may be infeasible.
#
# ==================== RESULTS ====================
# Objective Value: 450000.00
#
# EDGE FLOWS AND TRAVEL TIMES:
# ------------------------------------------------------------
# Edge                 Flow       Travel Time     Capacity Usage
# ------------------------------------------------------------
# Başlangıç1 -> Bit1            1000       120.00          100.0
# Başlangıç1 -> Bit2            1000       150.00          100.0
# Başlangıç1 -> Bit3            1000       180.00          100.0
# ------------------------------------------------------------
#
# PATH FLOWS:
# --------------------------------------------------------------------------------
# Source          Target          Path #       Flow       Time
# --------------------------------------------------------------------------------
# Başlangıç1      Bit1                1       1000     120.00
#     Path: Başlangıç1 -> Bit1
# Başlangıç1      Bit2                1       1000     150.00
#     Path: Başlangıç1 -> Bit2
# Başlangıç1      Bit3                1       1000     180.00
#     Path: Başlangıç1 -> Bit3
#
# PATH TIME SUMMARY:
# Minimum Path Time: 120.00
# Maximum Path Time: 180.00
# Flow-Weighted Average Path Time: 150.00
#
# ===== Single Phase ANALİZİ =====
# Toplam Akış Miktarı: 3000
# Ortalama Seyahat Süresi: 150.00
# En Yüksek Kapasite Kullanımı: 100.0% (Kenar: ('Başlangıç1', 'Bit1'))
# Tüm Kenarlar İçin Toplam Seyahat Süresi: 450000.00

# %%
edges = [
    # From Başlangıç nodes
    ("Başlangıç1", "Ara1"),
    ("Başlangıç2", "Ara2"),
    ("Ara1", "Bit3"), ("Ara1", "Ara2"), ("Ara2", "Bit1"),
    ("Başlangıç3", "Ara4"),
    ("Ara4", "Bit2"),
]

capacity = {
    ("Başlangıç1", "Ara1"): 1000,
    ("Başlangıç2", "Ara2"):1000,
    ("Ara1", "Bit3"):1000, ("Ara1", "Ara2"):1000, ("Ara2", "Bit1"):1000,
    ("Başlangıç3", "Ara4"):1000,
    ("Ara4", "Bit2"):1000,
}

travel_time = {
    ("Başlangıç1", "Ara1"):12,
    ("Başlangıç2", "Ara2"):80,
    ("Ara1", "Bit3"):240, ("Ara1", "Ara2"):24, ("Ara2", "Bit1"):48,
    ("Başlangıç3", "Ara4"):150,
    ("Ara4", "Bit2"):150,
}

passengers = {
    "Başlangıç1": 800,
    "Başlangıç2": 300,
    "Başlangıç3": 300
}

# %%
run_single_phase_optimization()
# Out:
# SINGLE PHASE OPTIMIZATION
# -------------------------
#
# ========= BAŞLANGIÇ NOKTALARI YOLCU DAĞILIMI =========
# --------------------------------------------------
# Başlangıç Noktası       Yolcu Sayısı
# --------------------------------------------------
# Başlangıç1                       800
# Başlangıç2                       300
# Başlangıç3                       300
# --------------------------------------------------
# TOPLAM                         1,400
# --------------------------------------------------
# Ipopt 3.14.17: max_iter=5000
# tol=1e-06
# output_file=ipopt_log.txt
#
# ==> Warning: Treating 0 binary and 11 integer variables as continuous.
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.17, running with linear solver MUMPS 5.7.3.
#
# Number of nonzeros in equality constraint Jacobian...:       34
# Number of nonzeros in inequality constraint Jacobian.:        7
# Number of nonzeros in Lagrangian Hessian.............:       14
#
# Total number of variables............................:       18
#                      variables with only lower bounds:       18
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       17
# Total number of inequality constraints...............:        7
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        7
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.9999860e-04 8.00e+02 1.25e-03  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.8626514e+05 1.40e+02 7.99e+04  -1.0 8.00e+02    -  1.24e-05 1.00e+00h  1
#    2  4.0338547e+05 1.67e-01 4.29e+02  -1.0 1.30e+02    -  4.36e-01 1.00e+00h  1
#    3  3.3276484e+05 2.64e+01 5.29e+01  -1.0 2.35e+02    -  5.38e-01 1.00e+00f  1
#    4  3.4447944e+05 7.55e-01 1.49e+00  -1.0 3.97e+01    -  8.86e-01 1.00e+00h  1
#    5  3.4483481e+05 7.96e-04 1.43e-03  -1.0 1.29e+00    -  9.95e-01 1.00e+00h  1
#    6  3.4483518e+05 4.49e-09 2.00e-07  -1.7 3.06e-03    -  1.00e+00 1.00e+00h  1
#    7  3.4483518e+05 8.84e-12 1.50e-09  -3.8 1.36e-04    -  1.00e+00 1.00e+00h  1
#    8  3.4483518e+05 5.68e-14 1.85e-11  -5.7 1.02e-06    -  1.00e+00 1.00e+00h  1
#    9  3.4483518e+05 5.68e-14 9.23e-13  -7.0 1.20e-08    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 9
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.4483518185090082e+05    3.4483518185090082e+05
# Dual infeasibility......:   9.2250801992591049e-13    9.2250801992591049e-13
# Constraint violation....:   5.6843418860808015e-14    5.6843418860808015e-14
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0909091053846767e-08    9.0909091053846767e-08
# Overall NLP error.......:   9.0909091053846767e-08    9.0909091053846767e-08
#
#
# Number of objective function evaluations             = 10
# Number of objective gradient evaluations             = 10
# Number of equality constraint evaluations            = 10
# Number of inequality constraint evaluations          = 10
# Number of equality constraint Jacobian evaluations   = 10
# Number of inequality constraint Jacobian evaluations = 10
# Number of Lagrangian Hessian evaluations             = 9
# Total seconds in IPOPT                               = 0.035
#
# EXIT: Optimal Solution Found.
#
# ==================== RESULTS ====================
# Objective Value: 344835.26
#
# EDGE FLOWS AND TRAVEL TIMES:
# ------------------------------------------------------------
# Edge                 Flow       Travel Time     Capacity Usage
# ------------------------------------------------------------
# Başlangıç1 -> Ara1            800        27.36           80.0
# Başlangıç2 -> Ara2            300        94.40           30.0
# Ara1 -> Bit3            245        268.81          24.5
# Ara1 -> Ara2            555        38.79           55.5
# Ara2 -> Bit1            855        118.18          85.5
# Başlangıç3 -> Ara4            300        177.00          30.0
# Ara4 -> Bit2            300        177.00          30.0
# ------------------------------------------------------------
#
# PATH FLOWS:
# --------------------------------------------------------------------------------
# Source          Target          Path #       Flow       Time
# --------------------------------------------------------------------------------
# Başlangıç1      Bit1                1        555     184.32
#     Path: Başlangıç1 -> Ara1 -> Ara2 -> Bit1
# Başlangıç1      Bit3                1        245     296.17
#     Path: Başlangıç1 -> Ara1 -> Bit3
# Başlangıç2      Bit1                1        300     212.58
#     Path: Başlangıç2 -> Ara2 -> Bit1
# Başlangıç3      Bit2                1        300     354.00
#     Path: Başlangıç3 -> Ara4 -> Bit2
#
# PATH TIME SUMMARY:
# Minimum Path Time: 184.32
# Maximum Path Time: 354.00
# Flow-Weighted Average Path Time: 246.31
#
# ===== Single Phase ANALİZİ =====
# Toplam Akış Miktarı: 3355
# Ortalama Seyahat Süresi: 128.79
# En Yüksek Kapasite Kullanımı: 85.5% (Kenar: ('Ara2', 'Bit1'))
# Tüm Kenarlar İçin Toplam Seyahat Süresi: 344835.26

# %%
# Yeni ağ yapısı
edges = [
    ('Başlangıç51', 'Başlangıç52'), ('Başlangıç51', 'Ara64'), 
    ('Başlangıç52', 'Başlangıç51'), ('Başlangıç52', 'Başlangıç56'), ('Başlangıç52', 'Ara64'),
    ('Başlangıç56', 'Başlangıç57'), ('Başlangıç57', 'Başlangıç56'), ('Başlangıç56', 'Ara65'),
    ('Başlangıç57', 'Başlangıç67'), ('Başlangıç57', 'Başlangıç56'), ('Başlangıç57', 'Ara66'),
    ('Başlangıç67', 'Başlangıç57'), ('Başlangıç67', 'Başlangıç68'), ('Başlangıç67', 'Ara76'),
    ('Başlangıç68', 'Başlangıç67'), ('Başlangıç68', 'Başlangıç70'), ('Başlangıç68', 'Ara77'),
    ('Başlangıç70', 'Başlangıç68'), ('Başlangıç70', 'Ara78'),
    ('Ara64', 'Ara65'), ('Ara64', 'Ara74'),
    ('Ara65', 'Ara66'), ('Ara65', 'Ara72'),
    ('Ara66', 'Ara73'), 
    ('Ara72', 'Ara73'), ('Ara72', 'Ara74'),
    ('Ara73', 'Ara75'),
    ('Ara74', 'Ara75'),
    ('Ara75', 'Ara76'), ('Ara75', 'Bit79'),
    ('Ara76', 'Ara77'), ('Ara76', 'Bit80'),
    ('Ara77', 'Ara78'),
    ('Ara78', 'Bit81'),
]

# Yeni seyahat süreleri
travel_time = {
    ('Başlangıç51', 'Başlangıç52'):0, ('Başlangıç51', 'Ara64'):90, 
    ('Başlangıç52', 'Başlangıç51'):0, ('Başlangıç52', 'Başlangıç56'):0, ('Başlangıç52', 'Ara64'): 36,
    ('Başlangıç56', 'Başlangıç57'):0, ('Başlangıç57', 'Başlangıç56'):0, ('Başlangıç56', 'Ara65'): 27,
    ('Başlangıç57', 'Başlangıç67'):0, ('Başlangıç57', 'Başlangıç56'):0, ('Başlangıç57', 'Ara66'): 34.20,
    ('Başlangıç67', 'Başlangıç57'):0, ('Başlangıç67', 'Başlangıç68'):0, ('Başlangıç67', 'Ara76'): 50.4,
    ('Başlangıç68', 'Başlangıç67'):0, ('Başlangıç68', 'Başlangıç70'):0, ('Başlangıç68', 'Ara77'): 68.4,
    ('Başlangıç70', 'Başlangıç68'):0, ('Başlangıç70', 'Ara78'): 72.00,
    ('Ara64', 'Ara65'): 86.4, ('Ara64', 'Ara74'): 90,
    ('Ara65', 'Ara66'): 79.2, ('Ara65', 'Ara72'): 14.4,
    ('Ara66', 'Ara73'): 23.4, 
    ('Ara72', 'Ara73'): 79.2, ('Ara72', 'Ara74'): 14.4,
    ('Ara73', 'Ara75'): 23.4,
    ('Ara74', 'Ara75'): 79.2,
    ('Ara75', 'Ara76'): 52.2, ('Ara75', 'Bit79'): 39.6,
    ('Ara76', 'Ara77'): 73.8, ('Ara76', 'Bit80'): 55.8,
    ('Ara77', 'Ara78'): 32.4,
    ('Ara78', 'Bit81'): 79.2,
}

# Yeni kapasiteler
capacity = {
    ('Başlangıç51', 'Başlangıç52'):1000000, ('Başlangıç51', 'Ara64'):2200, 
    ('Başlangıç52', 'Başlangıç51'):1000000, ('Başlangıç52', 'Başlangıç56'):1000000, ('Başlangıç52', 'Ara64'): 4400,
    ('Başlangıç56', 'Başlangıç57'):1000000, ('Başlangıç57', 'Başlangıç56'):1000000, ('Başlangıç56', 'Ara65'): 6600,
    ('Başlangıç57', 'Başlangıç67'):1000000, ('Başlangıç57', 'Başlangıç56'):1000000, ('Başlangıç57', 'Ara66'): 4400,
    ('Başlangıç67', 'Başlangıç57'):1000000, ('Başlangıç67', 'Başlangıç68'):1000000, ('Başlangıç67', 'Ara76'): 6600,
    ('Başlangıç68', 'Başlangıç67'):1000000, ('Başlangıç68', 'Başlangıç70'):1000000, ('Başlangıç68', 'Ara77'): 2200,
    ('Başlangıç70', 'Başlangıç68'):1000000, ('Başlangıç70', 'Ara78'): 6600,
    ('Ara64', 'Ara65'): 4400, ('Ara64', 'Ara74'): 4400,
    ('Ara65', 'Ara66'): 13200, ('Ara65', 'Ara72'): 6600,
    ('Ara66', 'Ara73'): 8800, 
    ('Ara72', 'Ara73'): 2200, ('Ara72', 'Ara74'): 4400,
    ('Ara73', 'Ara75'): 11000,
    ('Ara74', 'Ara75'): 6600,
    ('Ara75', 'Ara76'): 6600, ('Ara75', 'Bit79'): 11000,
    ('Ara76', 'Ara77'): 2200, ('Ara76', 'Bit80'): 11000,
    ('Ara77', 'Ara78'): 4400,
    ('Ara78', 'Bit81'): 11000,
}


# Yeni yolcu dağılımı - Daha güvenli yöntem
passengers = {
    "Başlangıç51": 4000,
    "Başlangıç52": 4000,
    "Başlangıç56": 4000,
    "Başlangıç57": 4000,
    "Başlangıç67": 4000,
    "Başlangıç68": 4000,
    "Başlangıç70": 4000,

}

# %%
run_single_phase_optimization()
# Out:
# SINGLE PHASE OPTIMIZATION
# -------------------------
#
# ========= BAŞLANGIÇ NOKTALARI YOLCU DAĞILIMI =========
# --------------------------------------------------
# Başlangıç Noktası       Yolcu Sayısı
# --------------------------------------------------
# Başlangıç51                    4,000
# Başlangıç52                    4,000
# Başlangıç56                    4,000
# Başlangıç57                    4,000
# Başlangıç67                    4,000
# Başlangıç68                    4,000
# Başlangıç70                    4,000
# --------------------------------------------------
# TOPLAM                        28,000
# --------------------------------------------------
# Ipopt 3.14.17: max_cpu_time=600
# tol=1e-06
#
# ==> Warning: Treating 0 binary and 193 integer variables as continuous.
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.17, running with linear solver MUMPS 5.7.3.
#
# Number of nonzeros in equality constraint Jacobian...:     1404
# Number of nonzeros in inequality constraint Jacobian.:       33
# Number of nonzeros in Lagrangian Hessian.............:       55
#
# Total number of variables............................:      226
#                      variables with only lower bounds:      226
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       73
# Total number of inequality constraints...............:       33
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       33
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  3.2999934e-03 4.00e+03 6.96e-03  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.1130996e-03 4.00e+03 3.08e+00  -1.0 1.00e+04    -  9.88e-07 4.06e-06f  1
#    2  1.5963893e-02 4.00e+03 3.09e+00  -1.0 1.16e+04    -  4.33e-06 8.57e-06f  1
#    3  6.1670604e-02 4.00e+03 3.09e+00  -1.0 1.08e+04    -  1.07e-05 3.73e-05f  1
#    4  3.7368797e-01 4.00e+03 3.08e+00  -1.0 1.14e+04    -  2.21e-05 1.49e-04h  1
#    5  9.1318348e+00 3.99e+03 3.39e+00  -1.0 1.26e+04    -  9.88e-05 1.10e-03h  1
#    6  3.2149962e+02 3.97e+03 5.55e+00  -1.0 1.32e+04    -  9.52e-04 6.89e-03h  1
#    7  7.9648532e+02 3.95e+03 5.60e+00  -1.0 1.87e+04    -  1.29e-03 4.82e-03h  1
#    8  1.9328645e+03 3.92e+03 5.60e+00  -1.0 1.47e+04    -  3.01e-03 7.08e-03h  1
#    9  4.8668057e+03 3.88e+03 5.60e+00  -1.0 1.22e+04    -  1.02e-03 1.14e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  8.7042137e+03 3.83e+03 5.57e+00  -1.0 1.51e+04    -  6.53e-04 1.13e-02h  1
#   11  8.7623986e+03 3.83e+03 5.57e+00  -1.0 1.38e+04    -  2.21e-03 1.46e-04h  1
#   12  8.7682819e+03 3.83e+03 5.57e+00  -1.0 1.59e+04    -  6.20e-04 1.52e-05h  1
#   13  1.1485583e+04 3.81e+03 5.54e+00  -1.0 1.59e+04    -  5.67e-05 6.53e-03h  1
#   14  1.1791141e+04 3.80e+03 5.54e+00  -1.0 1.27e+04    -  1.67e-03 7.02e-04h  1
#   15  1.5589872e+04 3.77e+03 6.56e+00  -1.0 1.91e+04    -  6.10e-04 9.79e-03h  1
#   16  5.3710270e+04 3.55e+03 1.13e+01  -1.0 1.38e+04    -  1.44e-02 5.73e-02h  1
#   17  5.5042114e+04 3.55e+03 1.13e+01  -1.0 9.11e+03    -  1.82e-03 1.37e-03h  1
#   18  5.8708795e+04 3.53e+03 1.17e+01  -1.0 1.04e+04    -  3.52e-04 3.94e-03h  1
#   19  5.8766727e+04 3.53e+03 1.14e+01  -1.0 1.69e+04    -  2.34e-03 6.39e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  6.5819870e+04 3.51e+03 1.22e+01  -1.0 1.61e+04    -  6.15e-04 7.30e-03h  1
#   21  6.7482353e+04 3.50e+03 1.09e+01  -1.0 1.53e+04    -  1.14e-02 1.65e-03h  1
#   22  6.8046664e+04 3.50e+03 1.07e+01  -1.0 1.07e+04    -  2.50e-03 5.27e-04h  1
#   23  7.0357041e+04 3.49e+03 1.09e+01  -1.0 1.12e+04    -  2.10e-04 2.12e-03h  1
#   24  7.6860517e+04 3.47e+03 1.13e+01  -1.0 1.12e+04    -  2.11e-03 5.79e-03h  1
#   25  8.5735327e+04 3.44e+03 1.15e+01  -1.0 1.11e+04    -  5.04e-03 7.52e-03h  1
#   26  2.3331088e+05 3.13e+03 1.77e+01  -1.0 1.07e+04    -  3.54e-02 9.21e-02h  1
#   27  4.0984164e+05 2.89e+03 2.51e+01  -1.0 8.55e+03    -  1.41e-02 7.65e-02h  1
#   28  4.1437925e+05 2.88e+03 2.52e+01  -1.0 8.27e+03    -  5.77e-04 1.76e-03h  1
#   29  6.7797674e+05 2.62e+03 3.57e+01  -1.0 8.60e+03    -  1.30e-03 8.97e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  8.3617889e+05 2.50e+03 3.88e+01  -1.0 7.63e+03    -  1.73e-02 4.72e-02h  1
#   31  9.0707298e+05 2.45e+03 4.10e+01  -1.0 7.49e+03    -  1.08e-03 2.02e-02h  1
#   32  1.3242484e+06 2.19e+03 5.38e+01  -1.0 7.68e+03    -  9.84e-04 1.07e-01h  1
#   33  2.1876636e+06 1.77e+03 7.23e+01  -1.0 6.68e+03    -  1.65e-02 1.90e-01h  1
#   34  3.6007554e+06 1.28e+03 3.50e+01  -1.0 5.36e+03    -  3.79e-01 2.80e-01h  1
#   35  4.3938004e+06 1.06e+03 1.56e+01  -1.0 3.85e+03    -  3.09e-01 1.70e-01h  1
#   36  5.3515564e+06 8.27e+02 1.43e+01  -1.0 3.21e+03    -  1.71e-01 2.18e-01h  1
#   37  5.4069721e+06 8.15e+02 1.42e+01  -1.0 3.27e+03    -  9.87e-03 1.49e-02h  1
#   38  5.4838594e+06 7.98e+02 1.49e+01  -1.0 2.49e+03    -  6.25e-04 2.07e-02h  1
#   39  5.4853355e+06 7.97e+02 1.40e+01  -1.0 2.53e+03    -  1.97e-02 4.04e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  5.5817500e+06 7.76e+02 1.44e+01  -1.0 2.59e+03    -  7.03e-03 2.63e-02h  1
#   41  5.8032715e+06 7.29e+02 1.52e+01  -1.0 2.40e+03    -  2.23e-02 6.08e-02h  1
#   42  8.0691694e+06 2.97e+02 6.64e+01  -1.0 2.25e+03    -  2.73e-01 5.93e-01h  1
#   43  8.1385540e+06 2.86e+02 5.30e+01  -1.0 8.39e+02    -  9.92e-02 3.69e-02h  1
#   44  8.3065072e+06 2.60e+02 6.25e+01  -1.0 8.09e+02    -  2.64e-03 9.19e-02h  1
#   45  8.8023346e+06 1.84e+02 8.26e+01  -1.0 7.73e+02    -  4.54e-02 2.92e-01h  1
#   46  8.8494919e+06 1.77e+02 9.65e+01  -1.0 6.43e+02    -  7.16e-01 3.79e-02h  1
#   47  8.9764642e+06 1.58e+02 1.04e+02  -1.0 8.80e+02    -  1.86e-01 1.05e-01h  1
#   48  9.8584809e+06 3.36e+01 6.06e+01  -1.0 5.87e+02    -  9.40e-01 7.88e-01h  1
#   49  1.0117134e+07 3.32e-01 1.11e+03  -1.0 2.77e+02    -  5.54e-02 9.90e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  1.0120438e+07 1.01e-05 3.25e+04  -1.0 2.71e+02    -  7.27e-01 1.00e+00h  1
#   51  1.0120438e+07 4.27e-09 5.68e+06  -1.0 9.50e+02    -  4.27e-01 1.00e+00f  1
#   52  1.0120438e+07 2.97e-11 5.46e+05  -1.0 1.16e+03    -  9.04e-01 1.00e+00f  1
#   53  1.0120438e+07 2.09e-11 3.69e+05  -1.0 5.52e+03    -  3.24e-01 3.04e-01f  1
#   54  1.0120438e+07 7.22e-12 2.19e+03  -1.0 3.02e+03    -  9.94e-01 1.00e+00f  1
#   55  1.0120432e+07 4.97e-06 9.72e-06  -1.7 2.77e+02    -  1.00e+00 1.00e+00f  1
#   56  1.0120431e+07 3.21e-07 6.25e+01  -5.7 9.29e-02    -  1.00e+00 1.00e+00f  1
#   57  1.0120431e+07 4.60e-12 6.61e-09  -5.7 6.59e-05  -4.0 1.00e+00 1.00e+00h  1
#   58  1.0120431e+07 3.92e-12 2.98e-09  -5.7 8.90e-05  -4.5 1.00e+00 1.00e+00h  1
#   59  1.0120431e+07 2.85e-12 9.24e+01  -7.0 1.32e-05  -5.0 1.00e+00 4.73e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  1.0120431e+07 4.94e-12 1.25e-12  -7.0 3.52e+02    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 60
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.0120430725387504e+07    1.0120430725387504e+07
# Dual infeasibility......:   1.2524791263018056e-12    1.2524791263018056e-12
# Constraint violation....:   4.9382720135326963e-12    4.9382720135326963e-12
# Variable bound violation:   9.5725386867832297e-09    9.5725386867832297e-09
# Complementarity.........:   1.1077165079415242e-07    1.1077165079415242e-07
# Overall NLP error.......:   1.1077165079415242e-07    1.1077165079415242e-07
#
#
# Number of objective function evaluations             = 61
# Number of objective gradient evaluations             = 61
# Number of equality constraint evaluations            = 61
# Number of inequality constraint evaluations          = 61
# Number of equality constraint Jacobian evaluations   = 61
# Number of inequality constraint Jacobian evaluations = 61
# Number of Lagrangian Hessian evaluations             = 60
# Total seconds in IPOPT                               = 0.218
#
# EXIT: Optimal Solution Found.
#
# ==================== RESULTS ====================
# Objective Value: 10120430.76
#
# EDGE FLOWS AND TRAVEL TIMES:
# ------------------------------------------------------------
# Edge                 Flow       Travel Time     Capacity Usage
# ------------------------------------------------------------
# Başlangıç51 -> Başlangıç52     4000       0.00            0.4
# Başlangıç51 -> Ara64           0          90.00           0.0
# Başlangıç52 -> Başlangıç51     0          0.00            0.0
# Başlangıç52 -> Başlangıç56     5882       0.00            0.6
# Başlangıç52 -> Ara64           2118       52.68           48.1
# Başlangıç56 -> Başlangıç57     7572       0.00            0.8
# Başlangıç57 -> Başlangıç56     4041       0.00            0.4
# Başlangıç56 -> Ara65           6351       77.00           96.2
# Başlangıç57 -> Başlangıç67     8534       0.00            0.9
# Başlangıç57 -> Başlangıç56     4041       0.00            0.4
# Başlangıç57 -> Ara66           4400       102.60          100.0
# Başlangıç67 -> Başlangıç57     5403       0.00            0.5
# Başlangıç67 -> Başlangıç68     6823       0.00            0.7
# Başlangıç67 -> Ara76           6600       151.20          100.0
# Başlangıç68 -> Başlangıç67     6292       0.00            0.6
# Başlangıç68 -> Başlangıç70     5860       0.00            0.6
# Başlangıç68 -> Ara77           2029       184.76          92.2
# Başlangıç70 -> Başlangıç68     3358       0.00            0.3
# Başlangıç70 -> Ara78           6502       211.76          98.5
# Ara64 -> Ara65           411        87.91           9.3
# Ara64 -> Ara74           1707       117.09          38.8
# Ara65 -> Ara66           3221       88.63           24.4
# Ara65 -> Ara72           3541       22.69           53.7
# Ara66 -> Ara73           7621       58.50           86.6
# Ara72 -> Ara73           1095       118.44          49.8
# Ara72 -> Ara74           2446       23.30           55.6
# Ara73 -> Ara75           8716       52.78           79.2
# Ara74 -> Ara75           4153       141.92          62.9
# Ara75 -> Ara76           1869       60.57           28.3
# Ara75 -> Bit79           11000      118.80          100.0
# Ara76 -> Ara77           0          73.80           0.0
# Ara76 -> Bit80           8469       121.95          77.0
# Ara77 -> Ara78           2029       46.18           46.1
# Ara78 -> Bit81           8531       174.47          77.6
# ------------------------------------------------------------
#
# PATH FLOWS:
# --------------------------------------------------------------------------------
# Source          Target          Path #       Flow       Time
# --------------------------------------------------------------------------------
# Başlangıç51     Bit79               2        787     430.49
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara74 -> Ara75 -> Bit79
# Başlangıç51     Bit79               6        416     332.68
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç51     Bit79               7         47     459.31
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç51     Bit79               8        283     395.72
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç51     Bit79               9         35     453.30
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç51     Bit79              10         91     389.72
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç51     Bit79              11         45     447.30
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç51     Bit79              12        220     383.71
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç51     Bit80               2        672     273.15
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Ara76 -> Bit80
# Başlangıç51     Bit80               3         67     494.22
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80               7         58     459.44
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80               8         62     396.41
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80               9         29     523.03
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80              10         41     453.44
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80              11         23     517.03
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80              12         55     447.43
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80              13         28     511.02
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit81               2        779     386.23
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Başlangıç68 -> Başlangıç70 -> Ara78 -> Bit81
# Başlangıç51     Bit81               5        264     405.41
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Başlangıç68 -> Ara77 -> Ara78 -> Bit81
# Başlangıç52     Bit79               1        787     430.49
#     Path: Başlangıç52 -> Ara64 -> Ara74 -> Ara75 -> Bit79
# Başlangıç52     Bit79               3         47     459.31
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç52     Bit79               4        416     332.68
#     Path: Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç52     Bit79               5         35     453.30
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç52     Bit79               6        283     395.72
#     Path: Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç52     Bit79               7         45     447.30
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç52     Bit79               8         91     389.72
#     Path: Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç52     Bit79               9        220     383.71
#     Path: Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç52     Bit80               1        672     273.15
#     Path: Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Ara76 -> Bit80
# Başlangıç52     Bit80               2         67     494.22
#     Path: Başlangıç52 -> Ara64 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80               4         58     459.44
#     Path: Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80               5         62     396.41
#     Path: Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80               6         29     523.03
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80               7         41     453.44
#     Path: Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80               8         23     517.03
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80               9         55     447.43
#     Path: Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80              10         28     511.02
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit81               1        779     386.23
#     Path: Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Başlangıç68 -> Başlangıç70 -> Ara78 -> Bit81
# Başlangıç52     Bit81               4        264     405.41
#     Path: Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Başlangıç68 -> Ara77 -> Ara78 -> Bit81
# Başlangıç56     Bit79               1        523     332.68
#     Path: Başlangıç56 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç56     Bit79               2        320     395.72
#     Path: Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç56     Bit79               3         95     389.72
#     Path: Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç56     Bit79               4        240     383.71
#     Path: Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç56     Bit80               1       1016     273.15
#     Path: Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Ara76 -> Bit80
# Başlangıç56     Bit80               2         60     459.44
#     Path: Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç56     Bit80               3         64     396.41
#     Path: Başlangıç56 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç56     Bit80               4         41     453.44
#     Path: Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç56     Bit80               5         57     447.43
#     Path: Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç56     Bit81               1       1279     386.23
#     Path: Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Başlangıç68 -> Başlangıç70 -> Ara78 -> Bit81
# Başlangıç56     Bit81               3        304     405.41
#     Path: Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Başlangıç68 -> Ara77 -> Ara78 -> Bit81
# Başlangıç57     Bit79               1        521     332.68
#     Path: Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç57     Bit79               2        375     395.72
#     Path: Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç57     Bit79               3         99     389.72
#     Path: Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç57     Bit79               4        274     383.71
#     Path: Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç57     Bit80               1        957     273.15
#     Path: Başlangıç57 -> Başlangıç67 -> Ara76 -> Bit80
# Başlangıç57     Bit80               2         64     396.41
#     Path: Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç57     Bit80               3         61     459.44
#     Path: Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç57     Bit80               4         42     453.44
#     Path: Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç57     Bit80               5         58     447.43
#     Path: Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç57     Bit81               1       1246     386.23
#     Path: Başlangıç57 -> Başlangıç67 -> Başlangıç68 -> Başlangıç70 -> Ara78 -> Bit81
# Başlangıç57     Bit81               3        303     405.41
#     Path: Başlangıç57 -> Başlangıç67 -> Başlangıç68 -> Ara77 -> Ara78 -> Bit81
# Başlangıç67     Bit79               1        628     332.68
#     Path: Başlangıç67 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç67     Bit79               2        432     395.72
#     Path: Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç67     Bit79               3        102     389.72
#     Path: Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç67     Bit79               4        301     383.71
#     Path: Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç67     Bit80               1        701     273.15
#     Path: Başlangıç67 -> Ara76 -> Bit80
# Başlangıç67     Bit80               2         66     396.41
#     Path: Başlangıç67 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç67     Bit80               3         63     459.44
#     Path: Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç67     Bit80               4         43     453.44
#     Path: Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç67     Bit80               5         59     447.43
#     Path: Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç67     Bit81               1       1302     386.23
#     Path: Başlangıç67 -> Başlangıç68 -> Başlangıç70 -> Ara78 -> Bit81
# Başlangıç67     Bit81               3        304     405.41
#     Path: Başlangıç67 -> Başlangıç68 -> Ara77 -> Ara78 -> Bit81
# Başlangıç68     Bit79               1        741     332.68
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç68     Bit79               2        484     395.72
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç68     Bit79               3        104     389.72
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç68     Bit79               4        326     383.71
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç68     Bit80               1       1337     273.15
#     Path: Başlangıç68 -> Başlangıç67 -> Ara76 -> Bit80
# Başlangıç68     Bit80               2         67     396.41
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç68     Bit80               3         64     459.44
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç68     Bit80               4         43     453.44
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç68     Bit80               5         60     447.43
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç68     Bit81               1        476     386.23
#     Path: Başlangıç68 -> Başlangıç70 -> Ara78 -> Bit81
# Başlangıç68     Bit81               2        299     405.41
#     Path: Başlangıç68 -> Ara77 -> Ara78 -> Bit81
# Başlangıç70     Bit79               1        704     332.68
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç70     Bit79               2        466     395.72
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç70     Bit79               3        104     389.72
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç70     Bit79               4        317     383.71
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç70     Bit80               1       1244     273.15
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Ara76 -> Bit80
# Başlangıç70     Bit80               2         66     396.41
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç70     Bit80               3         63     459.44
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç70     Bit80               4         43     453.44
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç70     Bit80               5         60     447.43
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç70     Bit81               1        642     386.23
#     Path: Başlangıç70 -> Ara78 -> Bit81
# Başlangıç70     Bit81               2        290     405.41
#     Path: Başlangıç70 -> Başlangıç68 -> Ara77 -> Ara78 -> Bit81
#
# PATH TIME SUMMARY:
# Minimum Path Time: 273.15
# Maximum Path Time: 523.03
# Flow-Weighted Average Path Time: 361.46
#
# ===== Single Phase ANALİZİ =====
# Toplam Akış Miktarı: 154615
# Ortalama Seyahat Süresi: 64.03
# En Yüksek Kapasite Kullanımı: 100.0% (Kenar: ('Başlangıç57', 'Ara66'))
# Tüm Kenarlar İçin Toplam Seyahat Süresi: 10120430.76
#
# Her Kenarın Toplam Seyahat Süreleri:
#   Kenar ('Başlangıç51', 'Başlangıç52'): 0.00
#   Kenar ('Başlangıç51', 'Ara64'): 0.00
#   Kenar ('Başlangıç52', 'Başlangıç51'): 0.00
#   Kenar ('Başlangıç52', 'Başlangıç56'): 0.00
#   Kenar ('Başlangıç52', 'Ara64'): 111582.99
#   Kenar ('Başlangıç56', 'Başlangıç57'): 0.00
#   Kenar ('Başlangıç57', 'Başlangıç56'): 0.00
#   Kenar ('Başlangıç56', 'Ara65'): 489041.70
#   Kenar ('Başlangıç57', 'Başlangıç67'): 0.00
#   Kenar ('Başlangıç57', 'Ara66'): 451440.00
#   Kenar ('Başlangıç67', 'Başlangıç57'): 0.00
#   Kenar ('Başlangıç67', 'Başlangıç68'): 0.00
#   Kenar ('Başlangıç67', 'Ara76'): 997920.00
#   Kenar ('Başlangıç68', 'Başlangıç67'): 0.00
#   Kenar ('Başlangıç68', 'Başlangıç70'): 0.00
#   Kenar ('Başlangıç68', 'Ara77'): 374878.65
#   Kenar ('Başlangıç70', 'Başlangıç68'): 0.00
#   Kenar ('Başlangıç70', 'Ara78'): 1376833.51
#   Kenar ('Ara64', 'Ara65'): 36130.07
#   Kenar ('Ara64', 'Ara74'): 199875.31
#   Kenar ('Ara65', 'Ara66'): 285482.62
#   Kenar ('Ara65', 'Ara72'): 80345.42
#   Kenar ('Ara66', 'Ara73'): 445826.85
#   Kenar ('Ara72', 'Ara73'): 129692.70
#   Kenar ('Ara72', 'Ara74'): 56992.30
#   Kenar ('Ara73', 'Ara75'): 460055.91
#   Kenar ('Ara74', 'Ara75'): 589384.83
#   Kenar ('Ara75', 'Ara76'): 113209.14
#   Kenar ('Ara75', 'Bit79'): 1306800.00
#   Kenar ('Ara76', 'Ara77'): 0.00
#   Kenar ('Ara76', 'Bit80'): 1032811.63
#   Kenar ('Ara77', 'Ara78'): 93698.22
#   Kenar ('Ara78', 'Bit81'): 1488428.88
