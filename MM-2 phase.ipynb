# %% [markdown]
# ## Model

# %%
import pyomo.environ as pyo
import networkx as nx
import matplotlib.pyplot as plt
from itertools import islice

def k_shortest_paths(G, source, target, k):
    """
    Finds the k shortest paths between two nodes.
    """
    return list(islice(nx.shortest_simple_paths(G, source, target), k))

def create_graph(edges, capacity):
    """
    Creates a directed graph from the given edges.
    """
    G = nx.DiGraph()
    for (i, j) in edges:
        G.add_edge(i, j, capacity=capacity[(i, j)])
    return G

def create_evacuation_model(edges, passengers, capacity, base_travel_time, K=100):
    """
    Creates the evacuation optimization model and minimizes 
    the maximum value of the flow/travel_time ratio.
    """
    G = create_graph(edges, capacity)
    
    model = pyo.ConcreteModel()
    
    all_nodes = set([i for (i, j) in edges] + [j for (i, j) in edges])
    baslangic_nodes = sorted(set(n for n in all_nodes if n.startswith('Başlangıç')))
    bitis_nodes = sorted(set(n for n in all_nodes if n.startswith('Bit')))
    
    model.edges = pyo.Set(initialize=edges)
    model.baslangic_nodes = pyo.Set(initialize=baslangic_nodes)
    model.bitis_nodes = pyo.Set(initialize=bitis_nodes)
    
    paths = {}
    for s in baslangic_nodes:
        for t in bitis_nodes:
            try:
                paths[(s, t)] = k_shortest_paths(G, s, t, K)
            except:
                continue
    
    # Path set
    model.paths = pyo.Set(initialize=[(s, t, k) for (s, t) in paths.keys() 
                                      for k in range(len(paths[(s, t)]))])
    
    # Variables
    model.edge_flow = pyo.Var(model.edges, domain=pyo.NonNegativeIntegers)
    model.path_flow = pyo.Var(model.paths, domain=pyo.NonNegativeIntegers)
    model.travel_time = pyo.Var(model.edges, domain=pyo.NonNegativeReals)
    
    model.Z = pyo.Var(domain=pyo.NonNegativeReals)
    
    def objective_rule(model):
        return model.Z
    model.objective = pyo.Objective(rule=objective_rule, sense=pyo.minimize)
    
    # Constraints
    def demand_rule(model, s):
        return sum(model.path_flow[s, t, k] for t in model.bitis_nodes 
                   for k in range(len(paths.get((s, t), [])))
                   if (s, t, k) in model.paths) == passengers[s]
    model.demand = pyo.Constraint(model.baslangic_nodes, rule=demand_rule)
    
    def capacity_rule(model, i, j):
        return model.edge_flow[i, j] <= capacity[(i, j)]
    model.capacity = pyo.Constraint(model.edges, rule=capacity_rule)
    
    def flow_conservation(model, i, j):
        path_sum = sum(model.path_flow[s, t, k] 
                       for (s, t, k) in model.paths 
                       if (i, j) in zip(paths[(s, t)][k][:-1], paths[(s, t)][k][1:]))
        return model.edge_flow[i, j] == path_sum
    model.flow_conservation = pyo.Constraint(model.edges, rule=flow_conservation)
    
    def travel_time_rule(model, i, j):
        return model.travel_time[i, j] == base_travel_time[(i, j)] * \
               (1 + 2 * (model.edge_flow[i, j] / capacity[(i, j)])**2)
    model.travel_time_constraint = pyo.Constraint(model.edges, rule=travel_time_rule)
    
    def max_flow_constraint(model, i, j):
        return model.Z * model.travel_time[i, j] >= model.edge_flow[i, j]
    model.max_flow_constraint = pyo.Constraint(model.edges, rule=max_flow_constraint)
    
    return model, paths, G

def solve_model(model, base_time_dict, cap_dict):
    solver = pyo.SolverFactory('ipopt')
    solver.options['max_iter'] = 10000  
    solver.options['tol'] = 1e-6
    solver.options['print_level'] = 4  

    # First solution
    results = solver.solve(model, tee=True)

    for edge in model.edges:
        current_flow = pyo.value(model.edge_flow[edge])
        model.edge_flow[edge].set_value(round(current_flow))

    for path in model.paths:
        current_flow = pyo.value(model.path_flow[path])
        model.path_flow[path].set_value(round(current_flow))

    for i, j in model.edges:
        current_flow = pyo.value(model.edge_flow[i, j])
        base_time = base_time_dict[(i, j)]
        cap = cap_dict[(i, j)]
        new_time = base_time * (1 + 2 * (current_flow / cap)**2)
        model.travel_time[i, j].set_value(new_time)

    return results

# %% [markdown]
# ## Printing

# %%
import random
import numpy as np
import pyomo.environ as pyo
import matplotlib.pyplot as plt

def print_results(model, edges, capacity, G, paths):
    """
    Display and visualize the results.
    """
    print("\n==================== RESULTS ====================")
    print(f"Objective Value: {pyo.value(model.objective):.2f}")
    
    # Print Edge Flow Table
    print("\nEDGE FLOWS AND TRAVEL TIMES:")
    print("-" * 60)
    print(f"{'Edge':<20} {'Flow':<10} {'Travel Time':<15} {'Capacity Usage':<15}")
    print("-" * 60)
    
    flow_values = {}
    total_flow = 0
    total_travel_time = 0
    total_capacity_usage = 0
    
    for (i, j) in edges:
        flow = int(round(pyo.value(model.edge_flow[i, j])))
        flow_values[(i, j)] = flow
        total_flow += flow
        time = pyo.value(model.travel_time[i, j])
        total_travel_time += time
        capacity_usage = (flow / capacity[(i, j)]) * 100
        total_capacity_usage += capacity_usage
        
        print(f"{i} -> {j:<15} {flow:<10} {time:<15.2f} {capacity_usage:<15.1f}")
    
    print("-" * 60)
    
    print("\nPATH FLOWS:")
    print("-" * 80)
    print(f"{'Source':<15} {'Target':<15} {'Path #':<5} {'Flow':>10} {'Time':>10}")
    print("-" * 80)
    
    path_times = []
    path_flow_weighted_times = []
    total_path_flows = []
    
    for s in model.baslangic_nodes:
        for t in model.bitis_nodes:
            for k in range(len(paths.get((s, t), []))):
                if (s, t, k) in model.path_flow:
                    flow = int(round(pyo.value(model.path_flow[s, t, k])))
                    if flow > 0:
                        total_path_flows.append(flow)
                        path = paths[(s, t)][k]
                        total_time = 0
                        individual_times = []
                        
                        for i in range(len(path) - 1):
                            edge = (path[i], path[i + 1])
                            edge_time = pyo.value(model.travel_time[edge])
                            total_time += edge_time
                            individual_times.append(edge_time)
                        
                        # Append path time and weighted flow*time for later calculations
                        path_times.append(total_time)
                        path_flow_weighted_times.append(flow * total_time)
                        
                        print(f"{s:<15} {t:<15} {k + 1:>5} {flow:>10} {total_time:>10.2f}")
                        print(f"    Path: {' -> '.join(path)}")
    
    if total_path_flows:
        max_path_time = max(path_times) if path_times else 0
        min_path_time = min(path_times) if path_times else 0
        total_path_flow = sum(total_path_flows)
        weighted_avg_time = (
            sum(path_flow_weighted_times) / total_path_flow if total_path_flow > 0 else 0
        )
        
        print("\nPATH TIME SUMMARY:")
        print(f"Minimum Path Time: {min_path_time:.2f}")
        print(f"Maximum Path Time: {max_path_time:.2f}")
        print(f"Flow-Weighted Average Path Time: {weighted_avg_time:.2f}")


def print_passenger_distribution(passengers):
    print("\n========= PASSENGER DISTRIBUTION AT START POINTS =========")
    print("-" * 50)
    print(f"{'Start Point':<20} {'Passenger Count':>15}")
    print("-" * 50) 
    
    total_passengers = 0
    for node, count in passengers.items():
        if node.startswith('Başlangıç') and count > 0:
            print(f"{node:<20} {count:>15,}")
            total_passengers += count
    
    print("-" * 50)
    print(f"{'TOTAL':<20} {total_passengers:>15,}")
    print("-" * 50)
    
    return total_passengers

def analyze_model(model, edges, capacity, stage_label):
    print(f"\n===== {stage_label} ANALYSIS =====")
    
    # Total flow amount
    total_flow = sum(pyo.value(model.edge_flow[e]) for e in edges)
    
    # Average travel time
    avg_travel_time = sum(pyo.value(model.travel_time[e]) for e in edges) / len(edges)
    
    # Capacity utilization rates
    max_utilization = 0
    most_congested_edge = None
    utilizations = []
    
    # Calculate total travel times
    total_travel_time = 0
    edge_travel_times = {}
    
    for e in edges:
        flow = pyo.value(model.edge_flow[e])
        travel_time = pyo.value(model.travel_time[e])
        cap = capacity[e]
        util = flow / cap if cap > 0 else 0
        utilizations.append(util)

        if util > max_utilization:
            max_utilization = util
            most_congested_edge = e
        
        # Total travel time for each edge
        edge_total_time = flow * travel_time
        edge_travel_times[e] = edge_total_time
        total_travel_time += edge_total_time

    # Print results
    print(f"Total Flow Amount: {total_flow}")
    print(f"Average Travel Time: {avg_travel_time:.2f}")
    print(f"Highest Capacity Utilization: {max_utilization*100:.1f}% (Edge: {most_congested_edge})")
    print(f"Total Travel Time for All Edges: {total_travel_time:.2f}")
    
    # Create histogram of capacity utilization rates
    plt.figure(figsize=(10, 6))
    plt.hist(utilizations, bins=20, color='blue', alpha=0.7)
    plt.title(f"{stage_label} - Capacity Utilization Distribution")
    plt.xlabel("Capacity Utilization Rate")
    plt.ylabel("Number of Edges")
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Visualization

# %%
def visualize_two_stages(model1, edges1, capacity1, G1, model2, edges2, capacity2, G2):
    """
    Stage 1 ve Stage 2 ağlarını üst üste görselleştirir.
    Kenar renkleri kapasite kullanımına göre %25 aralıklarla değişir.
    Ara düğümler bağlantılarına bağlı olarak sola veya sağa kaydırılır.
    """
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(20, 20))
    
    # Her aşama için gerekli parametreleri bir listeye toplayarak döngüyle işleyelim
    stages = [
        (ax1, model1, capacity1, G1, "Stage 1"),
        (ax2, model2, capacity2, G2, "Stage 2")
    ]
    
    for ax, model, capacity, G, stage_label in stages:
        # Genel konumlandırma için spring layout kullanımı
        pos = nx.spring_layout(G, seed=42)
        
        # Düğümleri kategorilere ayırma
        start_nodes = sorted(n for n in G.nodes() if n.startswith('Başlangıç'))
        finish_nodes = sorted(n for n in G.nodes() if n.startswith('Bit'))
        other_nodes = sorted(set(G.nodes()) - set(start_nodes) - set(finish_nodes))
        
        # Başlangıç düğümlerini hizalama (sol taraf)
        for i, node in enumerate(start_nodes):
            y = 1 - 2 * i / (len(start_nodes) - 1) if len(start_nodes) > 1 else 0
            pos[node] = (-1, y)
        
        # Bitiş düğümlerini hizalama (sağ taraf)
        for i, node in enumerate(finish_nodes):
            y = 1 - 2 * i / (len(finish_nodes) - 1) if len(finish_nodes) > 1 else 0
            pos[node] = (1, y)
        
        # Ara düğümleri hizalama (orta), bağlantılarına göre sola/sağa kaydırma
        for i, node in enumerate(other_nodes):
            y = 1 - 2 * i / (len(other_nodes) - 1) if len(other_nodes) > 1 else 0
            x_positions = []
            # Gelen kenarlar için sola kaydırma
            for pred in G.predecessors(node):
                if pred in other_nodes:
                    x_positions.append(-0.5)
            # Giden kenarlar için sağa kaydırma
            for succ in G.successors(node):
                if succ in other_nodes:
                    x_positions.append(0.5)
            x = sum(x_positions) / len(x_positions) if x_positions else 0
            pos[node] = (x, y)
        
        # Düğümleri çizme
        nx.draw_networkx_nodes(G, pos, ax=ax, node_size=300, node_color='lightblue')
        nx.draw_networkx_labels(G, pos, ax=ax, font_size=8)
        
        # Kenar renklerini akışa göre belirleme
        edge_colors = []
        for (u, v) in G.edges():
            # Akışı güvenli bir şekilde al
            try:
                flow = pyo.value(model.edge_flow[u, v])
            except KeyError:
                flow = 0
            cap = capacity.get((u, v), None)
            ratio = flow / cap if cap and cap > 0 else 0
            
            # Kapasite kullanımına göre kenar rengini belirle
            if ratio <= 0.25:
                edge_colors.append('green')
            elif ratio <= 0.5:
                edge_colors.append('yellow')
            elif ratio <= 0.75:
                edge_colors.append('orange')
            else:
                edge_colors.append('red')
        
        nx.draw_networkx_edges(G, pos, ax=ax, edge_color=edge_colors, arrowsize=10)
        ax.set_title(stage_label)
        ax.axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
def create_stage_two_network(original_total_passengers):
# Eşit oranlar
    oranlar = np.repeat(1.0 / len(baslangic_noktalari), len(baslangic_noktalari))
    
    # Yeni yolcuların dağılımı
    new_passengers = {}
    for i, node in enumerate(baslangic_noktalari):
        new_passengers[node] = int(original_total_passengers * oranlar[i])
    
    
    # Yuvarlama hatalarını düzelt
    toplam = sum(new_passengers.values())
    if toplam != original_total_passengers:
        fark = original_total_passengers - toplam
        new_passengers[baslangic_noktalari[0]] += fark
    
    return new_edges, new_travel_time, new_capacity, new_passengers
    
def run_two_stage_optimization():
    # AŞAMA 1
    print("STAGE 1 -")
    print("-------------------------")
    toplam_yolcu = print_passenger_distribution(passengers)
    model1, paths1, G1 = create_evacuation_model(edges, passengers, capacity, travel_time)
    results1 = solve_model(model1, travel_time, capacity)
    if results1:
        print_results(model1, edges, capacity, G1, paths1)
        analyze_model(model1, edges, capacity, "Stage 1")
    
    # AŞAMA 2
    print("\STAGE 2 ")
    print("-------------------------")
    new_edges, new_travel_time, new_capacity, new_passengers = create_stage_two_network(toplam_yolcu)
    print_passenger_distribution(new_passengers)
    model2, paths2, G2 = create_evacuation_model(new_edges, new_passengers, new_capacity, new_travel_time)
    results2 = solve_model(model2, new_travel_time, new_capacity)
    if results2:
        print_results(model2, new_edges, new_capacity, G2, paths2)
        analyze_model(model2, new_edges, new_capacity, "Stage 2")
    
    visualize_two_stages(model1, edges, capacity, G1, model2, new_edges, new_capacity, G2)


# Modeli çalıştır

# if __name__ == "__main__":
    # run_two_stage_optimization()

# %% [markdown]
# ## TestCase1

# %%
edges = [
    # From Başlangıç nodes
    ("Başlangıç1", "Ara10"),
    ("Başlangıç2", "Ara11"),
    ("Başlangıç3", "Ara13"),
    ("Başlangıç3", "Ara12"),
    ("Başlangıç3", "Başlangıç4"),
    ("Başlangıç4", "Başlangıç3"),
    ("Başlangıç4", "Başlangıç5"),
    ("Başlangıç5", "Ara13"),
    ("Başlangıç5", "Başlangıç4"),
    ("Başlangıç6", "Ara14"),
    ("Başlangıç6", "Başlangıç7"),
    ("Başlangıç7", "Başlangıç6"),
    ("Başlangıç8", "Ara21"),
    ("Başlangıç9", "Ara24"),

    # Intermediate connections
    ("Ara10", "Ara16"),
    ("Ara11", "Ara10"),
    ("Ara11", "Ara12"),
    ("Ara11", "Ara17"),
    ("Ara12", "Ara18"),
    ("Ara13", "Ara14"),
    ("Ara13", "Ara19"),
    ("Ara14", "Ara15"),
    ("Ara15", "Ara20"),
    ("Ara15", "Ara35"),
    ("Ara16", "Ara28"),
    ("Ara17", "Ara16"),
    ("Ara17", "Ara18"),
    ("Ara18", "Ara19"),
    ("Ara19", "Ara20"),
    ("Ara20", "Ara34"),
    ("Ara21", "Ara22"),
    ("Ara21", "Ara35"),
    ("Ara22", "Ara23"),
    ("Ara22", "Bit45"),
    ("Ara23", "Bit46"),
    ("Ara24", "Ara25"),
    ("Ara24", "Ara36"),
    ("Ara25", "Ara26"),
    ("Ara25", "Ara37"),
    ("Ara26", "Ara27"),
    ("Ara26", "Ara38"),
    ("Ara27", "Ara39"),
    ("Ara28", "Bit29"),
    ("Ara28", "Bit50"),
    ("Ara32", "Bit31"),
    ("Ara32", "Bit40"),
    ("Ara33", "Ara32"),
    ("Ara33", "Bit41"),
    ("Ara34", "Bit42"),
    ("Ara34", "Ara33"),
    ("Ara35", "Ara34"),
    ("Ara35", "Bit44"),
    ("Ara36", "Ara37"),
    ("Ara36", "Bit47"),
    ("Ara37", "Ara38"),
    ("Ara37", "Bit48"),
    ("Ara38", "Ara39"),
    ("Ara39", "Bit49"),
]

travel_time = {
    # From Başlangıç nodes
    ("Başlangıç1", "Ara10"): 32.4,
    ("Başlangıç2", "Ara11"): 18,
    ("Başlangıç3", "Ara13"): 21.6,
    ("Başlangıç3", "Ara12"): 19.8,
    ("Başlangıç3", "Başlangıç4"): 0,
    ("Başlangıç4", "Başlangıç3"): 0,
    ("Başlangıç4", "Başlangıç5"): 0,
    ("Başlangıç5", "Ara13"): 37.8,
    ("Başlangıç5", "Başlangıç4"): 0,
    ("Başlangıç6", "Ara14"): 27,
    ("Başlangıç6", "Başlangıç7"): 0,
    ("Başlangıç7", "Başlangıç6"): 0,
    ("Başlangıç8", "Ara21"): 63,
    ("Başlangıç9", "Ara24"): 34.2,

    # Intermediate connections
    ("Ara10", "Ara16"): 43.2,
    ("Ara11", "Ara10"): 77.4,
    ("Ara11", "Ara12"): 68,
    ("Ara11", "Ara17"): 18,
    ("Ara12", "Ara18"): 27,
    ("Ara13", "Ara14"): 54,
    ("Ara13", "Ara19"): 34.2,
    ("Ara14", "Ara15"): 10.8,
    ("Ara15", "Ara20"): 21.6,
    ("Ara15", "Ara35"): 55.8,
    ("Ara16", "Ara28"): 176.4,
    ("Ara17", "Ara16"): 14,
    ("Ara17", "Ara18"): 12,
    ("Ara18", "Ara19"): 27,
    ("Ara19", "Ara20"): 66.6,
    ("Ara20", "Ara34"): 46.8,
    ("Ara21", "Ara22"): 41.4,
    ("Ara21", "Ara35"): 18,
    ("Ara22", "Ara23"): 32.4,
    ("Ara22", "Bit45"): 81,
    ("Ara23", "Bit46"): 77.4,
    ("Ara24", "Ara25"): 21.6,
    ("Ara24", "Ara36"): 25.2,
    ("Ara25", "Ara26"): 52.2,
    ("Ara25", "Ara37"): 25.2,
    ("Ara26", "Ara27"): 48.6,
    ("Ara26", "Ara38"): 25.2,
    ("Ara27", "Ara39"): 28.8,
    ("Ara28", "Bit29"): 50.4,
    ("Ara28", "Bit50"): 45,
    ("Ara32", "Bit31"): 19.8,
    ("Ara32", "Bit40"): 27,
    ("Ara33", "Ara32"): 10.8,
    ("Ara33", "Bit41"): 32.4,
    ("Ara34", "Bit42"): 45,
    ("Ara34", "Ara33"): 63,
    ("Ara35", "Ara34"): 48.6,
    ("Ara35", "Bit44"): 100.8,
    ("Ara36", "Ara37"): 21.6,
    ("Ara36", "Bit47"): 70.2,
    ("Ara37", "Ara38"): 18,
    ("Ara37", "Bit48"): 25,
    ("Ara38", "Ara39"): 50.4,
    ("Ara39", "Bit49"): 52.2,
}

capacity = {
    # From Başlangıç nodes
    ("Başlangıç1", "Ara10"): 4400,
    ("Başlangıç2", "Ara11"): 2200,
    ("Başlangıç3", "Ara13"): 2200,
    ("Başlangıç3", "Ara12"): 6600,
    ("Başlangıç3", "Başlangıç4"): 100000,
    ("Başlangıç4", "Başlangıç3"): 100000,
    ("Başlangıç4", "Başlangıç5"): 100000,
    ("Başlangıç5", "Ara13"): 4400,
    ("Başlangıç5", "Başlangıç4"): 100000,
    ("Başlangıç6", "Ara14"): 6600,
    ("Başlangıç6", "Başlangıç7"): 100000,
    ("Başlangıç7", "Başlangıç6"): 100000,
    ("Başlangıç8", "Ara21"): 4400,
    ("Başlangıç9", "Ara24"): 6600,

    # Intermediate connections
    ("Ara10", "Ara16"): 4400,
    ("Ara11", "Ara10"): 4400,
    ("Ara11", "Ara12"): 4400,
    ("Ara11", "Ara17"): 2200,
    ("Ara12", "Ara18"): 2200,
    ("Ara13", "Ara14"): 6600,
    ("Ara13", "Ara19"): 4400,
    ("Ara14", "Ara15"): 8800,
    ("Ara15", "Ara20"): 4400,
    ("Ara15", "Ara35"): 6600,
    ("Ara16", "Ara28"): 6600,
    ("Ara17", "Ara16"): 4400,
    ("Ara17", "Ara18"): 6600,
    ("Ara18", "Ara19"): 6600,
    ("Ara19", "Ara20"): 6600,
    ("Ara20", "Ara34"): 8800,
    ("Ara21", "Ara22"): 6600,
    ("Ara21", "Ara35"): 4400,
    ("Ara22", "Ara23"): 6600,
    ("Ara22", "Bit45"): 2200,
    ("Ara23", "Bit46"): 4400,
    ("Ara24", "Ara25"): 2200,
    ("Ara24", "Ara36"): 6600,
    ("Ara25", "Ara26"): 4400,
    ("Ara25", "Ara37"): 6600,
    ("Ara26", "Ara27"): 4400,
    ("Ara26", "Ara38"): 4400,
    ("Ara27", "Ara39"): 4400,
    ("Ara28", "Bit29"): 4400,
    ("Ara28", "Bit50"): 4400,
    ("Ara32", "Bit31"): 2200,
    ("Ara32", "Bit40"): 2200,
    ("Ara33", "Ara32"): 4400,
    ("Ara33", "Bit41"): 2200,
    ("Ara34", "Bit42"): 4400,
    ("Ara34", "Ara33"): 6600,
    ("Ara35", "Ara34"): 6600,
    ("Ara35", "Bit44"): 6600,
    ("Ara36", "Ara37"): 6600,
    ("Ara36", "Bit47"): 2200,
    ("Ara37", "Ara38"): 2200,
    ("Ara37", "Bit48"): 2200,
    ("Ara38", "Ara39"): 2200,
    ("Ara39", "Bit49"): 4400,
}

passengers = {
    "Başlangıç1": 2000,
    "Başlangıç2": 1000,
    "Başlangıç3": 2200,
    "Başlangıç4": 0,
    "Başlangıç5": 2800,
    "Başlangıç6": 3000,
    "Başlangıç7": 0,
    "Başlangıç8": 2000,
    "Başlangıç9": 3000,

    "Ara10": 0, "Ara11": 0, "Ara12": 0, "Ara13": 0, "Ara14": 0,
    "Ara15": 0, "Ara16": 0, "Ara17": 0, "Ara18": 0, "Ara19": 0,
    "Ara20": 0, "Ara21": 0, "Ara22": 0, "Ara23": 0, "Ara24": 0,
    "Ara25": 0, "Ara26": 0, "Ara27": 0, "Ara28": 0, "Bit29": 0,
    "Bit30": 0, "Bit31": 0, "Ara32": 0, "Ara33": 0, "Ara34": 0,
    "Ara35": 0, "Ara36": 0, "Ara37": 0, "Ara38": 0, "Ara39": 0,
    "Bit40": 0, "Bit41": 0, "Bit42": 0, "Bit43": 0, "Bit44": 0,
    "Bit45": 0, "Bit46": 0, "Bit47": 0, "Bit48": 0, "Bit49": 0,
    "Bit50": 0
}

# %%
# Yeni ağ yapısı
new_edges = [
    ('Başlangıç51', 'Başlangıç52'), ('Başlangıç51', 'Ara64'), 
    ('Başlangıç52', 'Başlangıç51'), ('Başlangıç52', 'Başlangıç56'), ('Başlangıç52', 'Ara64'),
    ('Başlangıç56', 'Başlangıç57'), ('Başlangıç57', 'Başlangıç56'), ('Başlangıç56', 'Ara65'),
    ('Başlangıç57', 'Başlangıç67'), ('Başlangıç57', 'Başlangıç56'), ('Başlangıç57', 'Ara66'),
    ('Başlangıç67', 'Başlangıç57'), ('Başlangıç67', 'Başlangıç68'), ('Başlangıç67', 'Ara76'),
    ('Başlangıç68', 'Başlangıç67'), ('Başlangıç68', 'Başlangıç70'), ('Başlangıç68', 'Ara77'),
    ('Başlangıç70', 'Başlangıç68'), ('Başlangıç70', 'Ara78'),
    ('Ara64', 'Ara65'), ('Ara64', 'Ara74'),
    ('Ara65', 'Ara66'), ('Ara65', 'Ara72'),
    ('Ara66', 'Ara73'), 
    ('Ara72', 'Ara73'), ('Ara72', 'Ara74'),
    ('Ara73', 'Ara75'),
    ('Ara74', 'Ara75'),
    ('Ara75', 'Ara76'), ('Ara75', 'Bit79'),
    ('Ara76', 'Ara77'), ('Ara76', 'Bit80'),
    ('Ara77', 'Ara78'),
    ('Ara78', 'Bit81'),
]

# Yeni seyahat süreleri
new_travel_time = {
    ('Başlangıç51', 'Başlangıç52'):0, ('Başlangıç51', 'Ara64'):90, 
    ('Başlangıç52', 'Başlangıç51'):0, ('Başlangıç52', 'Başlangıç56'):0, ('Başlangıç52', 'Ara64'): 36,
    ('Başlangıç56', 'Başlangıç57'):0, ('Başlangıç57', 'Başlangıç56'):0, ('Başlangıç56', 'Ara65'): 27,
    ('Başlangıç57', 'Başlangıç67'):0, ('Başlangıç57', 'Başlangıç56'):0, ('Başlangıç57', 'Ara66'): 34.20,
    ('Başlangıç67', 'Başlangıç57'):0, ('Başlangıç67', 'Başlangıç68'):0, ('Başlangıç67', 'Ara76'): 50.4,
    ('Başlangıç68', 'Başlangıç67'):0, ('Başlangıç68', 'Başlangıç70'):0, ('Başlangıç68', 'Ara77'): 68.4,
    ('Başlangıç70', 'Başlangıç68'):0, ('Başlangıç70', 'Ara78'): 72.00,
    ('Ara64', 'Ara65'): 86.4, ('Ara64', 'Ara74'): 90,
    ('Ara65', 'Ara66'): 79.2, ('Ara65', 'Ara72'): 14.4,
    ('Ara66', 'Ara73'): 23.4, 
    ('Ara72', 'Ara73'): 79.2, ('Ara72', 'Ara74'): 14.4,
    ('Ara73', 'Ara75'): 23.4,
    ('Ara74', 'Ara75'): 79.2,
    ('Ara75', 'Ara76'): 52.2, ('Ara75', 'Bit79'): 39.6,
    ('Ara76', 'Ara77'): 73.8, ('Ara76', 'Bit80'): 55.8,
    ('Ara77', 'Ara78'): 32.4,
    ('Ara78', 'Bit81'): 79.2,
}

# Yeni kapasiteler
new_capacity = {
    ('Başlangıç51', 'Başlangıç52'):1000000, ('Başlangıç51', 'Ara64'):2200, 
    ('Başlangıç52', 'Başlangıç51'):1000000, ('Başlangıç52', 'Başlangıç56'):1000000, ('Başlangıç52', 'Ara64'): 4400,
    ('Başlangıç56', 'Başlangıç57'):1000000, ('Başlangıç57', 'Başlangıç56'):1000000, ('Başlangıç56', 'Ara65'): 6600,
    ('Başlangıç57', 'Başlangıç67'):1000000, ('Başlangıç57', 'Başlangıç56'):1000000, ('Başlangıç57', 'Ara66'): 4400,
    ('Başlangıç67', 'Başlangıç57'):1000000, ('Başlangıç67', 'Başlangıç68'):1000000, ('Başlangıç67', 'Ara76'): 6600,
    ('Başlangıç68', 'Başlangıç67'):1000000, ('Başlangıç68', 'Başlangıç70'):1000000, ('Başlangıç68', 'Ara77'): 2200,
    ('Başlangıç70', 'Başlangıç68'):1000000, ('Başlangıç70', 'Ara78'): 6600,
    ('Ara64', 'Ara65'): 4400, ('Ara64', 'Ara74'): 4400,
    ('Ara65', 'Ara66'): 13200, ('Ara65', 'Ara72'): 6600,
    ('Ara66', 'Ara73'): 8800, 
    ('Ara72', 'Ara73'): 2200, ('Ara72', 'Ara74'): 4400,
    ('Ara73', 'Ara75'): 11000,
    ('Ara74', 'Ara75'): 6600,
    ('Ara75', 'Ara76'): 6600, ('Ara75', 'Bit79'): 11000,
    ('Ara76', 'Ara77'): 2200, ('Ara76', 'Bit80'): 11000,
    ('Ara77', 'Ara78'): 4400,
    ('Ara78', 'Bit81'): 11000,
}

# Yeni yolcu dağılımı - Daha güvenli yöntem
baslangic_noktalari = ['Başlangıç51', 'Başlangıç52', 'Başlangıç56', 'Başlangıç57', 'Başlangıç67', 'Başlangıç68', 'Başlangıç70']

# %%
run_two_stage_optimization()
# Out:
# STAGE 1 -
# -------------------------
#
# ========= PASSENGER DISTRIBUTION AT START POINTS =========
# --------------------------------------------------
# Start Point          Passenger Count
# --------------------------------------------------
# Başlangıç1                     2,000
# Başlangıç2                     1,000
# Başlangıç3                     2,200
# Başlangıç5                     2,800
# Başlangıç6                     3,000
# Başlangıç8                     2,000
# Başlangıç9                     3,000
# --------------------------------------------------
# TOTAL                         16,000
# --------------------------------------------------
# Ipopt 3.14.17: max_iter=10000
# tol=1e-06
# print_level=4
#
# ==> Warning: Treating 0 binary and 194 integer variables as continuous.
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# Total number of variables............................:      253
#                      variables with only lower bounds:      253
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      125
# Total number of inequality constraints...............:      116
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      116
#
#
# Number of Iterations....: 70
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.2538884413046819e+02    2.2538884413046819e+02
# Dual infeasibility......:   1.9440174901457564e-11    1.9440174901457564e-11
# Constraint violation....:   6.0254023992456504e-12    6.0254023992456504e-12
# Variable bound violation:   2.3319886601166266e-11    2.3319886601166266e-11
# Complementarity.........:   9.0909094711957166e-08    9.0909094711957166e-08
# Overall NLP error.......:   9.0909094711957166e-08    9.0909094711957166e-08
#
#
# Number of objective function evaluations             = 91
# Number of objective gradient evaluations             = 39
# Number of equality constraint evaluations            = 91
# Number of inequality constraint evaluations          = 91
# Number of equality constraint Jacobian evaluations   = 72
# Number of inequality constraint Jacobian evaluations = 72
# Number of Lagrangian Hessian evaluations             = 70
# Total seconds in IPOPT                               = 0.250
#
# EXIT: Optimal Solution Found.
#
# ==================== RESULTS ====================
# Objective Value: 225.39
#
# EDGE FLOWS AND TRAVEL TIMES:
# ------------------------------------------------------------
# Edge                 Flow       Travel Time     Capacity Usage
# ------------------------------------------------------------
# Başlangıç1 -> Ara10           2000       45.79           45.5
# Başlangıç2 -> Ara11           1000       25.44           45.5
# Başlangıç3 -> Ara13           961        29.84           43.7
# Başlangıç3 -> Ara12           1239       21.20           18.8
# Başlangıç3 -> Başlangıç4      0          0.00            0.0
# Başlangıç4 -> Başlangıç3      0          0.00            0.0
# Başlangıç4 -> Başlangıç5      0          0.00            0.0
# Başlangıç5 -> Ara13           2800       68.41           63.6
# Başlangıç5 -> Başlangıç4      0          0.00            0.0
# Başlangıç6 -> Ara14           3000       38.16           45.5
# Başlangıç6 -> Başlangıç7      0          0.00            0.0
# Başlangıç7 -> Başlangıç6      0          0.00            0.0
# Başlangıç8 -> Ara21           2000       89.03           45.5
# Başlangıç9 -> Ara24           3000       48.33           45.5
# Ara10 -> Ara16           2198       64.76           50.0
# Ara11 -> Ara10           198        77.71           4.5
# Ara11 -> Ara12           284        68.57           6.5
# Ara11 -> Ara17           518        20.00           23.5
# Ara12 -> Ara18           1523       52.88           69.2
# Ara13 -> Ara14           0          54.00           0.0
# Ara13 -> Ara19           3761       84.18           85.5
# Ara14 -> Ara15           3000       13.31           34.1
# Ara15 -> Ara20           1147       24.54           26.1
# Ara15 -> Ara35           1853       64.60           28.1
# Ara16 -> Ara28           2411       223.48          36.5
# Ara17 -> Ara16           213        14.07           4.8
# Ara17 -> Ara18           305        12.05           4.6
# Ara18 -> Ara19           1828       31.14           27.7
# Ara19 -> Ara20           5589       162.12          84.7
# Ara20 -> Ara34           6736       101.64          76.5
# Ara21 -> Ara22           992        43.27           15.0
# Ara21 -> Ara35           1008       19.89           22.9
# Ara22 -> Ara23           582        32.90           8.8
# Ara22 -> Bit45           409        86.60           18.6
# Ara23 -> Bit46           582        80.11           13.2
# Ara24 -> Ara25           1738       48.56           79.0
# Ara24 -> Ara36           1262       27.04           19.1
# Ara25 -> Ara26           1052       58.17           23.9
# Ara25 -> Ara37           685        25.74           10.4
# Ara26 -> Ara27           593        50.37           13.5
# Ara26 -> Ara38           459        25.75           10.4
# Ara27 -> Ara39           593        29.85           13.5
# Ara28 -> Bit29           1207       57.99           27.4
# Ara28 -> Bit50           1204       51.74           27.4
# Ara32 -> Bit31           1808       46.55           82.2
# Ara32 -> Bit40           1804       63.31           82.0
# Ara33 -> Ara32           3612       25.36           82.1
# Ara33 -> Bit41           1834       77.43           83.4
# Ara34 -> Bit42           3298       95.56           75.0
# Ara34 -> Ara33           5447       148.82          82.5
# Ara35 -> Ara34           2008       57.60           30.4
# Ara35 -> Bit44           853        104.17          12.9
# Ara36 -> Ara37           891        22.39           13.5
# Ara36 -> Bit47           371        74.19           16.9
# Ara37 -> Ara38           924        24.35           42.0
# Ara37 -> Bit48           652        29.39           29.6
# Ara38 -> Ara39           1383       90.23           62.9
# Ara39 -> Bit49           1977       73.28           44.9
# ------------------------------------------------------------
#
# PATH FLOWS:
# --------------------------------------------------------------------------------
# Source          Target          Path #       Flow       Time
# --------------------------------------------------------------------------------
# Başlangıç1      Bit29               1       1002     392.01
#     Path: Başlangıç1 -> Ara10 -> Ara16 -> Ara28 -> Bit29
# Başlangıç1      Bit50               1        998     385.77
#     Path: Başlangıç1 -> Ara10 -> Ara16 -> Ara28 -> Bit50
# Başlangıç2      Bit29               1         99     449.38
#     Path: Başlangıç2 -> Ara11 -> Ara10 -> Ara16 -> Ara28 -> Bit29
# Başlangıç2      Bit29               2        107     340.96
#     Path: Başlangıç2 -> Ara11 -> Ara17 -> Ara16 -> Ara28 -> Bit29
# Başlangıç2      Bit31               1         69     662.51
#     Path: Başlangıç2 -> Ara11 -> Ara12 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç2      Bit31               2         74     573.11
#     Path: Başlangıç2 -> Ara11 -> Ara17 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç2      Bit40               1         69     679.27
#     Path: Başlangıç2 -> Ara11 -> Ara12 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç2      Bit40               2         74     589.87
#     Path: Başlangıç2 -> Ara11 -> Ara17 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç2      Bit41               1         69     668.04
#     Path: Başlangıç2 -> Ara11 -> Ara12 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç2      Bit41               2         74     578.64
#     Path: Başlangıç2 -> Ara11 -> Ara17 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç2      Bit42               1         76     537.35
#     Path: Başlangıç2 -> Ara11 -> Ara12 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Bit42
# Başlangıç2      Bit42               2         82     447.95
#     Path: Başlangıç2 -> Ara11 -> Ara17 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Bit42
# Başlangıç2      Bit50               1         99     443.13
#     Path: Başlangıç2 -> Ara11 -> Ara10 -> Ara16 -> Ara28 -> Bit50
# Başlangıç2      Bit50               2        107     334.72
#     Path: Başlangıç2 -> Ara11 -> Ara17 -> Ara16 -> Ara28 -> Bit50
# Başlangıç3      Bit31               1        217     598.50
#     Path: Başlangıç3 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç3      Bit31               2        270     589.70
#     Path: Başlangıç3 -> Ara12 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç3      Bit40               1        217     615.27
#     Path: Başlangıç3 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç3      Bit40               2        269     606.46
#     Path: Başlangıç3 -> Ara12 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç3      Bit41               1        219     604.03
#     Path: Başlangıç3 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç3      Bit41               2        274     595.23
#     Path: Başlangıç3 -> Ara12 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç3      Bit42               1        308     473.34
#     Path: Başlangıç3 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Bit42
# Başlangıç3      Bit42               2        426     464.54
#     Path: Başlangıç3 -> Ara12 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Bit42
# Başlangıç5      Bit31               1        478     637.07
#     Path: Başlangıç5 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç5      Bit40               1        476     653.84
#     Path: Başlangıç5 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç5      Bit41               1        489     642.60
#     Path: Başlangıç5 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç5      Bit42               1       1357     511.91
#     Path: Başlangıç5 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Bit42
# Başlangıç6      Bit31               1        253     398.37
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç6      Bit31               2        274     394.38
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç6      Bit40               1        253     415.13
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç6      Bit40               2        274     411.15
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç6      Bit41               1        256     403.90
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç6      Bit41               2        278     399.92
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Bit41
# Başlangıç6      Bit42               1        385     273.21
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Bit42
# Başlangıç6      Bit42               2        436     269.23
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Bit42
# Başlangıç6      Bit44               1        591     220.23
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara35 -> Bit44
# Başlangıç8      Bit31               1        173     387.24
#     Path: Başlangıç8 -> Ara21 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç8      Bit40               1        173     404.01
#     Path: Başlangıç8 -> Ara21 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç8      Bit41               1        175     392.77
#     Path: Başlangıç8 -> Ara21 -> Ara35 -> Ara34 -> Ara33 -> Bit41
# Başlangıç8      Bit42               1        226     262.08
#     Path: Başlangıç8 -> Ara21 -> Ara35 -> Ara34 -> Bit42
# Başlangıç8      Bit44               1        262     213.09
#     Path: Başlangıç8 -> Ara21 -> Ara35 -> Bit44
# Başlangıç8      Bit45               1        409     218.90
#     Path: Başlangıç8 -> Ara21 -> Ara22 -> Bit45
# Başlangıç8      Bit46               1        582     245.32
#     Path: Başlangıç8 -> Ara21 -> Ara22 -> Ara23 -> Bit46
# Başlangıç9      Bit47               1        371     149.57
#     Path: Başlangıç9 -> Ara24 -> Ara36 -> Bit47
# Başlangıç9      Bit48               1        291     152.03
#     Path: Başlangıç9 -> Ara24 -> Ara25 -> Ara37 -> Bit48
# Başlangıç9      Bit48               2        360     127.15
#     Path: Başlangıç9 -> Ara24 -> Ara36 -> Ara37 -> Bit48
# Başlangıç9      Bit49               1        593     308.55
#     Path: Başlangıç9 -> Ara24 -> Ara25 -> Ara26 -> Ara27 -> Ara39 -> Bit49
# Başlangıç9      Bit49               2        531     285.62
#     Path: Başlangıç9 -> Ara24 -> Ara36 -> Ara37 -> Ara38 -> Ara39 -> Bit49
# Başlangıç9      Bit49               3        394     310.50
#     Path: Başlangıç9 -> Ara24 -> Ara25 -> Ara37 -> Ara38 -> Ara39 -> Bit49
# Başlangıç9      Bit49               4        459     344.32
#     Path: Başlangıç9 -> Ara24 -> Ara25 -> Ara26 -> Ara38 -> Ara39 -> Bit49
#
# PATH TIME SUMMARY:
# Minimum Path Time: 127.15
# Maximum Path Time: 679.27
# Flow-Weighted Average Path Time: 402.57
#
# ===== Stage 1 ANALYSIS =====
# Total Flow Amount: 86792
# Average Travel Time: 51.82
# Highest Capacity Utilization: 85.5% (Edge: ('Ara13', 'Ara19'))
# Total Travel Time for All Edges: 6440908.02
# \STAGE 2
# -------------------------
#
# ========= PASSENGER DISTRIBUTION AT START POINTS =========
# --------------------------------------------------
# Start Point          Passenger Count
# --------------------------------------------------
# Başlangıç51                    2,290
# Başlangıç52                    2,285
# Başlangıç56                    2,285
# Başlangıç57                    2,285
# Başlangıç67                    2,285
# Başlangıç68                    2,285
# Başlangıç70                    2,285
# --------------------------------------------------
# TOTAL                         16,000
# --------------------------------------------------
# Ipopt 3.14.17: max_iter=10000
# tol=1e-06
# print_level=4
#
# ==> Warning: Treating 0 binary and 193 integer variables as continuous.
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# Total number of variables............................:      227
#                      variables with only lower bounds:      227
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       73
# Total number of inequality constraints...............:       66
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       66
#
#
# Number of Iterations....: 10000
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.3356339678195852e+05    4.3356339678195852e+05
# Dual infeasibility......:   8.0499822871054860e+05    8.0499822871054860e+05
# Constraint violation....:   6.9500081599653640e-01    6.9500081599653640e-01
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   1.9043801904532933e+02    1.9043801904532933e+02
# Overall NLP error.......:   1.5017092106607093e+01    8.0499822871054860e+05
#
#
# Number of objective function evaluations             = 112489
# Number of objective gradient evaluations             = 9973
# Number of equality constraint evaluations            = 112489
# Number of inequality constraint evaluations          = 112489
# Number of equality constraint Jacobian evaluations   = 10002
# Number of inequality constraint Jacobian evaluations = 10002
# Number of Lagrangian Hessian evaluations             = 10000
# Total seconds in IPOPT                               = 49.994
#
# EXIT: Maximum Number of Iterations Exceeded.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: maxIterations
#     - message from solver: Ipopt 3.14.17\x3a Maximum Number of Iterations
#       Exceeded.
#
# ==================== RESULTS ====================
# Objective Value: 433563.40
#
# EDGE FLOWS AND TRAVEL TIMES:
# ------------------------------------------------------------
# Edge                 Flow       Travel Time     Capacity Usage
# ------------------------------------------------------------
# Başlangıç51 -> Başlangıç52     89         0.00            0.0
# Başlangıç51 -> Ara64           2200       270.00          100.0
# Başlangıç52 -> Başlangıç51     0          0.00            0.0
# Başlangıç52 -> Başlangıç56     78         0.00            0.0
# Başlangıç52 -> Ara64           2295       55.59           52.2
# Başlangıç56 -> Başlangıç57     1          0.00            0.0
# Başlangıç57 -> Başlangıç56     75         0.00            0.0
# Başlangıç56 -> Ara65           2437       34.36           36.9
# Başlangıç57 -> Başlangıç67     350        0.00            0.0
# Başlangıç57 -> Başlangıç56     75         0.00            0.0
# Başlangıç57 -> Ara66           1862       46.45           42.3
# Başlangıç67 -> Başlangıç57     2          0.00            0.0
# Başlangıç67 -> Başlangıç68     0          0.00            0.0
# Başlangıç67 -> Ara76           2963       70.72           44.9
# Başlangıç68 -> Başlangıç67     330        0.00            0.0
# Başlangıç68 -> Başlangıç70     365        0.00            0.0
# Başlangıç68 -> Ara77           1590       139.86          72.3
# Başlangıç70 -> Başlangıç68     0          0.00            0.0
# Başlangıç70 -> Ara78           2649       95.20           40.1
# Ara64 -> Ara65           4374       257.16          99.4
# Ara64 -> Ara74           121        90.14           2.8
# Ara65 -> Ara66           6793       121.15          51.5
# Ara65 -> Ara72           18         14.40           0.3
# Ara66 -> Ara73           8655       68.67           98.4
# Ara72 -> Ara73           9          79.20           0.4
# Ara72 -> Ara74           8          14.40           0.2
# Ara73 -> Ara75           8664       52.43           78.8
# Ara74 -> Ara75           130        79.26           2.0
# Ara75 -> Ara76           6559       155.31          99.4
# Ara75 -> Bit79           2235       42.87           20.3
# Ara76 -> Ara77           3          73.80           0.1
# Ara76 -> Bit80           9520       139.39          86.5
# Ara77 -> Ara78           1592       40.88           36.2
# Ara78 -> Bit81           4242       102.76          38.6
# ------------------------------------------------------------
#
# PATH FLOWS:
# --------------------------------------------------------------------------------
# Source          Target          Path #       Flow       Time
# --------------------------------------------------------------------------------
# Başlangıç51     Bit79               1         27     482.27
#     Path: Başlangıç51 -> Ara64 -> Ara74 -> Ara75 -> Bit79
# Başlangıç51     Bit79               2         10     267.86
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara74 -> Ara75 -> Bit79
# Başlangıç51     Bit79               3        514     812.29
#     Path: Başlangıç51 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç51     Bit79               4          1     716.07
#     Path: Başlangıç51 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç51     Bit79               5          1     678.10
#     Path: Başlangıç51 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç51     Bit79               7         21     597.88
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç51     Bit79               8         12     319.49
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç51     Bit80               1         22     734.09
#     Path: Başlangıç51 -> Ara64 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80               3         10     519.68
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80               4       1634    1064.11
#     Path: Başlangıç51 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80               7         12     571.31
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80               9         22     849.70
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit79               1         30     267.86
#     Path: Başlangıç52 -> Ara64 -> Ara74 -> Ara75 -> Bit79
# Başlangıç52     Bit79               3        516     597.88
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç52     Bit79               5          1     501.66
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç52     Bit79               6         26     319.49
#     Path: Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç52     Bit79               7          1     463.68
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç52     Bit80               2         22     519.68
#     Path: Başlangıç52 -> Ara64 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80               4         27     571.31
#     Path: Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80               6       1661     849.70
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç56     Bit79               2        532     319.49
#     Path: Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç56     Bit79               3          4     223.27
#     Path: Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç56     Bit79               4          5     185.29
#     Path: Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç56     Bit80               2       1743     571.31
#     Path: Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç57     Bit79               1        496     210.42
#     Path: Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç57     Bit79               2         36     319.49
#     Path: Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç57     Bit80               1        350     210.11
#     Path: Başlangıç57 -> Başlangıç67 -> Ara76 -> Bit80
# Başlangıç57     Bit80               2       1365     462.25
#     Path: Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç57     Bit80               3         38     571.31
#     Path: Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç67     Bit80               1       2284     210.11
#     Path: Başlangıç67 -> Ara76 -> Bit80
# Başlangıç68     Bit80               1        329     210.11
#     Path: Başlangıç68 -> Başlangıç67 -> Ara76 -> Bit80
# Başlangıç68     Bit81               1        365     197.95
#     Path: Başlangıç68 -> Başlangıç70 -> Ara78 -> Bit81
# Başlangıç68     Bit81               2       1590     283.50
#     Path: Başlangıç68 -> Ara77 -> Ara78 -> Bit81
# Başlangıç70     Bit81               1       2284     197.95
#     Path: Başlangıç70 -> Ara78 -> Bit81
#
# PATH TIME SUMMARY:
# Minimum Path Time: 185.29
# Maximum Path Time: 1064.11
# Flow-Weighted Average Path Time: 471.17
#
# ===== Stage 2 ANALYSIS =====
# Total Flow Amount: 70284
# Average Travel Time: 60.12
# Highest Capacity Utilization: 100.0% (Edge: ('Başlangıç51', 'Ara64'))
# Total Travel Time for All Edges: 7537274.17

# %% [markdown]
# ## TestCase2

# %%
edges = [
    ("Başlangıç1", "Ara10"),
    ("Başlangıç2", "Ara11"),
    ("Başlangıç3", "Ara13"),
    ("Başlangıç3", "Ara12"),
    ("Başlangıç3", "Başlangıç4"),
    ("Başlangıç4", "Başlangıç3"),
    ("Başlangıç4", "Başlangıç5"),
    ("Başlangıç5", "Ara13"),
    ("Başlangıç5", "Başlangıç4"),
    ("Başlangıç6", "Ara14"),
    ("Başlangıç6", "Başlangıç7"),
    ("Başlangıç7", "Başlangıç6"),
    ("Başlangıç8", "Ara21"),
    ("Başlangıç9", "Ara24"),

    # Intermediate connections
    ("Ara10", "Ara16"),
    ("Ara11", "Ara10"),
    ("Ara11", "Ara12"),
    ("Ara11", "Ara17"),
    ("Ara12", "Ara18"),
    ("Ara13", "Ara14"),
    ("Ara13", "Ara19"),
    ("Ara14", "Ara15"),
    ("Ara15", "Ara20"),
    ("Ara15", "Ara35"),
    ("Ara16", "Ara28"),
    ("Ara17", "Ara16"),
    ("Ara17", "Ara18"),
    ("Ara18", "Ara19"),
    ("Ara19", "Ara20"),
    ("Ara20", "Ara34"),
    ("Ara21", "Ara22"),
    ("Ara21", "Ara35"),
    ("Ara22", "Ara23"),
    ("Ara22", "Bit45"),
    ("Ara23", "Bit46"),
    ("Ara24", "Ara25"),
    ("Ara24", "Ara36"),
    ("Ara25", "Ara26"),
    ("Ara25", "Ara37"),
    ("Ara26", "Ara27"),
    ("Ara26", "Ara38"),
    ("Ara27", "Ara39"),
    ("Ara28", "Bit29"),
    ("Ara28", "Bit50"),
    ("Ara32", "Bit31"),
    ("Ara32", "Bit40"),
    ("Ara33", "Ara32"),
    ("Ara33", "Bit41"),
    ("Ara34", "Bit42"),
    ("Ara34", "Ara33"),
    ("Ara35", "Ara34"),
    ("Ara35", "Bit44"),
    ("Ara36", "Ara37"),
    ("Ara36", "Bit47"),
    ("Ara37", "Ara38"),
    ("Ara37", "Bit48"),
    ("Ara38", "Ara39"),
    ("Ara39", "Bit49"),
]

travel_time = {
    # From Başlangıç nodes
    ("Başlangıç1", "Ara10"): 32.4,
    ("Başlangıç2", "Ara11"): 18,
    ("Başlangıç3", "Ara13"): 21.6,
    ("Başlangıç3", "Ara12"): 19.8,
    ("Başlangıç3", "Başlangıç4"): 0,
    ("Başlangıç4", "Başlangıç3"): 0,
    ("Başlangıç4", "Başlangıç5"): 0,
    ("Başlangıç5", "Ara13"): 37.8,
    ("Başlangıç5", "Başlangıç4"): 0,
    ("Başlangıç6", "Ara14"): 27,
    ("Başlangıç6", "Başlangıç7"): 0,
    ("Başlangıç7", "Başlangıç6"): 0,
    ("Başlangıç8", "Ara21"): 63,
    ("Başlangıç9", "Ara24"): 34.2,

    # Intermediate connections
    ("Ara10", "Ara16"): 43.2,
    ("Ara11", "Ara10"): 77.4,
    ("Ara11", "Ara12"): 68,
    ("Ara11", "Ara17"): 18,
    ("Ara12", "Ara18"): 27,
    ("Ara13", "Ara14"): 54,
    ("Ara13", "Ara19"): 34.2,
    ("Ara14", "Ara15"): 10.8,
    ("Ara15", "Ara20"): 21.6,
    ("Ara15", "Ara35"): 55.8,
    ("Ara16", "Ara28"): 176.4,
    ("Ara17", "Ara16"): 14,
    ("Ara17", "Ara18"): 12,
    ("Ara18", "Ara19"): 27,
    ("Ara19", "Ara20"): 66.6,
    ("Ara20", "Ara34"): 46.8,
    ("Ara21", "Ara22"): 41.4,
    ("Ara21", "Ara35"): 18,
    ("Ara22", "Ara23"): 32.4,
    ("Ara22", "Bit45"): 81,
    ("Ara23", "Bit46"): 77.4,
    ("Ara24", "Ara25"): 21.6,
    ("Ara24", "Ara36"): 25.2,
    ("Ara25", "Ara26"): 52.2,
    ("Ara25", "Ara37"): 25.2,
    ("Ara26", "Ara27"): 48.6,
    ("Ara26", "Ara38"): 25.2,
    ("Ara27", "Ara39"): 28.8,
    ("Ara28", "Bit29"): 50.4,
    ("Ara28", "Bit50"): 45,
    ("Ara32", "Bit31"): 19.8,
    ("Ara32", "Bit40"): 27,
    ("Ara33", "Ara32"): 10.8,
    ("Ara33", "Bit41"): 32.4,
    ("Ara34", "Bit42"): 45,
    ("Ara34", "Ara33"): 63,
    ("Ara35", "Ara34"): 48.6,
    ("Ara35", "Bit44"): 100.8,
    ("Ara36", "Ara37"): 21.6,
    ("Ara36", "Bit47"): 70.2,
    ("Ara37", "Ara38"): 18,
    ("Ara37", "Bit48"): 25,
    ("Ara38", "Ara39"): 50.4,
    ("Ara39", "Bit49"): 52.2,
}

capacity = {
    # From Başlangıç nodes
    ("Başlangıç1", "Ara10"): 4400,
    ("Başlangıç2", "Ara11"): 2200,
    ("Başlangıç3", "Ara13"): 2200,
    ("Başlangıç3", "Ara12"): 6600,
    ("Başlangıç3", "Başlangıç4"): 100000,
    ("Başlangıç4", "Başlangıç3"): 100000,
    ("Başlangıç4", "Başlangıç5"): 100000,
    ("Başlangıç5", "Ara13"): 4400,
    ("Başlangıç5", "Başlangıç4"): 100000,
    ("Başlangıç6", "Ara14"): 6600,
    ("Başlangıç6", "Başlangıç7"): 100000,
    ("Başlangıç7", "Başlangıç6"): 100000,
    ("Başlangıç8", "Ara21"): 4400,
    ("Başlangıç9", "Ara24"): 6600,

    # Intermediate connections
    ("Ara10", "Ara16"): 4400,
    ("Ara11", "Ara10"): 4400,
    ("Ara11", "Ara12"): 4400,
    ("Ara11", "Ara17"): 2200,
    ("Ara12", "Ara18"): 2200,
    ("Ara13", "Ara14"): 6600,
    ("Ara13", "Ara19"): 4400,
    ("Ara14", "Ara15"): 8800,
    ("Ara15", "Ara20"): 4400,
    ("Ara15", "Ara35"): 6600,
    ("Ara16", "Ara28"): 6600,
    ("Ara17", "Ara16"): 4400,
    ("Ara17", "Ara18"): 6600,
    ("Ara18", "Ara19"): 6600,
    ("Ara19", "Ara20"): 6600,
    ("Ara20", "Ara34"): 8800,
    ("Ara21", "Ara22"): 6600,
    ("Ara21", "Ara35"): 4400,
    ("Ara22", "Ara23"): 6600,
    ("Ara22", "Bit45"): 2200,
    ("Ara23", "Bit46"): 4400,
    ("Ara24", "Ara25"): 2200,
    ("Ara24", "Ara36"): 6600,
    ("Ara25", "Ara26"): 4400,
    ("Ara25", "Ara37"): 6600,
    ("Ara26", "Ara27"): 4400,
    ("Ara26", "Ara38"): 4400,
    ("Ara27", "Ara39"): 4400,
    ("Ara28", "Bit29"): 4400,
    ("Ara28", "Bit50"): 4400,
    ("Ara32", "Bit31"): 2200,
    ("Ara32", "Bit40"): 2200,
    ("Ara33", "Ara32"): 4400,
    ("Ara33", "Bit41"): 2200,
    ("Ara34", "Bit42"): 4400,
    ("Ara34", "Ara33"): 6600,
    ("Ara35", "Ara34"): 6600,
    ("Ara35", "Bit44"): 6600,
    ("Ara36", "Ara37"): 6600,
    ("Ara36", "Bit47"): 2200,
    ("Ara37", "Ara38"): 2200,
    ("Ara37", "Bit48"): 2200,
    ("Ara38", "Ara39"): 2200,
    ("Ara39", "Bit49"): 4400,
}

passengers = {
    "Başlangıç1": 4400,
    "Başlangıç2": 2200,
    "Başlangıç3": 4400,
    "Başlangıç4": 0,
    "Başlangıç5": 4400,
    "Başlangıç6": 3300,
    "Başlangıç7": 3300,
    "Başlangıç8": 4400,
    "Başlangıç9": 6600,

    "Ara10": 0, "Ara11": 0, "Ara12": 0, "Ara13": 0, "Ara14": 0,
    "Ara15": 0, "Ara16": 0, "Ara17": 0, "Ara18": 0, "Ara19": 0,
    "Ara20": 0, "Ara21": 0, "Ara22": 0, "Ara23": 0, "Ara24": 0,
    "Ara25": 0, "Ara26": 0, "Ara27": 0, "Ara28": 0, "Bit29": 0,
    "Bit30": 0, "Bit31": 0, "Ara32": 0, "Ara33": 0, "Ara34": 0,
    "Ara35": 0, "Ara36": 0, "Ara37": 0, "Ara38": 0, "Ara39": 0,
    "Bit40": 0, "Bit41": 0, "Bit42": 0, "Bit43": 0, "Bit44": 0,
    "Bit45": 0, "Bit46": 0, "Bit47": 0, "Bit48": 0, "Bit49": 0,
    "Bit50": 0
}

# %%
# Yeni ağ yapısı
new_edges = [
    ('Başlangıç51', 'Başlangıç52'), ('Başlangıç51', 'Ara64'), 
    ('Başlangıç52', 'Başlangıç51'), ('Başlangıç52', 'Başlangıç56'), ('Başlangıç52', 'Ara64'),
    ('Başlangıç56', 'Başlangıç57'), ('Başlangıç57', 'Başlangıç56'), ('Başlangıç56', 'Ara65'),
    ('Başlangıç57', 'Başlangıç67'), ('Başlangıç57', 'Başlangıç56'), ('Başlangıç57', 'Ara66'),
    ('Başlangıç67', 'Başlangıç57'), ('Başlangıç67', 'Başlangıç68'), ('Başlangıç67', 'Ara76'),
    ('Başlangıç68', 'Başlangıç67'), ('Başlangıç68', 'Başlangıç70'), ('Başlangıç68', 'Ara77'),
    ('Başlangıç70', 'Başlangıç68'), ('Başlangıç70', 'Ara78'),
    ('Ara64', 'Ara65'), ('Ara64', 'Ara74'),
    ('Ara65', 'Ara66'), ('Ara65', 'Ara72'),
    ('Ara66', 'Ara73'), 
    ('Ara72', 'Ara73'), ('Ara72', 'Ara74'),
    ('Ara73', 'Ara75'),
    ('Ara74', 'Ara75'),
    ('Ara75', 'Ara76'), ('Ara75', 'Bit79'),
    ('Ara76', 'Ara77'), ('Ara76', 'Bit80'),
    ('Ara77', 'Ara78'),
    ('Ara78', 'Bit81'),
]

# Yeni seyahat süreleri
new_travel_time = {
    ('Başlangıç51', 'Başlangıç52'):0, ('Başlangıç51', 'Ara64'):90, 
    ('Başlangıç52', 'Başlangıç51'):0, ('Başlangıç52', 'Başlangıç56'):0, ('Başlangıç52', 'Ara64'): 36,
    ('Başlangıç56', 'Başlangıç57'):0, ('Başlangıç57', 'Başlangıç56'):0, ('Başlangıç56', 'Ara65'): 27,
    ('Başlangıç57', 'Başlangıç67'):0, ('Başlangıç57', 'Başlangıç56'):0, ('Başlangıç57', 'Ara66'): 34.20,
    ('Başlangıç67', 'Başlangıç57'):0, ('Başlangıç67', 'Başlangıç68'):0, ('Başlangıç67', 'Ara76'): 50.4,
    ('Başlangıç68', 'Başlangıç67'):0, ('Başlangıç68', 'Başlangıç70'):0, ('Başlangıç68', 'Ara77'): 68.4,
    ('Başlangıç70', 'Başlangıç68'):0, ('Başlangıç70', 'Ara78'): 72.00,
    ('Ara64', 'Ara65'): 86.4, ('Ara64', 'Ara74'): 90,
    ('Ara65', 'Ara66'): 79.2, ('Ara65', 'Ara72'): 14.4,
    ('Ara66', 'Ara73'): 23.4, 
    ('Ara72', 'Ara73'): 79.2, ('Ara72', 'Ara74'): 14.4,
    ('Ara73', 'Ara75'): 23.4,
    ('Ara74', 'Ara75'): 79.2,
    ('Ara75', 'Ara76'): 52.2, ('Ara75', 'Bit79'): 39.6,
    ('Ara76', 'Ara77'): 73.8, ('Ara76', 'Bit80'): 55.8,
    ('Ara77', 'Ara78'): 32.4,
    ('Ara78', 'Bit81'): 79.2,
}

# Yeni kapasiteler
new_capacity = {
    ('Başlangıç51', 'Başlangıç52'):1000000, ('Başlangıç51', 'Ara64'):2200, 
    ('Başlangıç52', 'Başlangıç51'):1000000, ('Başlangıç52', 'Başlangıç56'):1000000, ('Başlangıç52', 'Ara64'): 4400,
    ('Başlangıç56', 'Başlangıç57'):1000000, ('Başlangıç57', 'Başlangıç56'):1000000, ('Başlangıç56', 'Ara65'): 6600,
    ('Başlangıç57', 'Başlangıç67'):1000000, ('Başlangıç57', 'Başlangıç56'):1000000, ('Başlangıç57', 'Ara66'): 4400,
    ('Başlangıç67', 'Başlangıç57'):1000000, ('Başlangıç67', 'Başlangıç68'):1000000, ('Başlangıç67', 'Ara76'): 6600,
    ('Başlangıç68', 'Başlangıç67'):1000000, ('Başlangıç68', 'Başlangıç70'):1000000, ('Başlangıç68', 'Ara77'): 2200,
    ('Başlangıç70', 'Başlangıç68'):1000000, ('Başlangıç70', 'Ara78'): 6600,
    ('Ara64', 'Ara65'): 4400, ('Ara64', 'Ara74'): 4400,
    ('Ara65', 'Ara66'): 13200, ('Ara65', 'Ara72'): 6600,
    ('Ara66', 'Ara73'): 8800, 
    ('Ara72', 'Ara73'): 2200, ('Ara72', 'Ara74'): 4400,
    ('Ara73', 'Ara75'): 11000,
    ('Ara74', 'Ara75'): 6600,
    ('Ara75', 'Ara76'): 6600, ('Ara75', 'Bit79'): 11000,
    ('Ara76', 'Ara77'): 2200, ('Ara76', 'Bit80'): 11000,
    ('Ara77', 'Ara78'): 4400,
    ('Ara78', 'Bit81'): 11000,
}

# Yeni yolcu dağılımı - Daha güvenli yöntem
baslangic_noktalari = ['Başlangıç51', 'Başlangıç52', 'Başlangıç56', 'Başlangıç57', 'Başlangıç67', 'Başlangıç68', 'Başlangıç70']

# %%
run_two_stage_optimization()
# Out:
# STAGE 1 -
# -------------------------
#
# ========= PASSENGER DISTRIBUTION AT START POINTS =========
# --------------------------------------------------
# Start Point          Passenger Count
# --------------------------------------------------
# Başlangıç1                     4,400
# Başlangıç2                     2,200
# Başlangıç3                     4,400
# Başlangıç5                     4,400
# Başlangıç6                     3,300
# Başlangıç7                     3,300
# Başlangıç8                     4,400
# Başlangıç9                     6,600
# --------------------------------------------------
# TOTAL                         33,000
# --------------------------------------------------
# Ipopt 3.14.17: max_iter=10000
# tol=1e-06
# print_level=4
#
# ==> Warning: Treating 0 binary and 194 integer variables as continuous.
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# Total number of variables............................:      253
#                      variables with only lower bounds:      253
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      125
# Total number of inequality constraints...............:      116
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      116
#
#
# Number of Iterations....: 10000
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.5335269902575910e+06    5.5335269902575910e+06
# Dual infeasibility......:   1.8339951663658461e+06    1.8339951663658461e+06
# Constraint violation....:   2.2352963208495567e+00    2.2352963208495567e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   1.0739015534365126e+03    1.0739015534365126e+03
# Overall NLP error.......:   3.0634762166751845e+00    1.8339951663658461e+06
#
#
# Number of objective function evaluations             = 101176
# Number of objective gradient evaluations             = 9962
# Number of equality constraint evaluations            = 101603
# Number of inequality constraint evaluations          = 101603
# Number of equality constraint Jacobian evaluations   = 10002
# Number of inequality constraint Jacobian evaluations = 10002
# Number of Lagrangian Hessian evaluations             = 10000
# Total seconds in IPOPT                               = 48.622
#
# EXIT: Maximum Number of Iterations Exceeded.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: maxIterations
#     - message from solver: Ipopt 3.14.17\x3a Maximum Number of Iterations
#       Exceeded.
#
# ==================== RESULTS ====================
# Objective Value: 5533526.99
#
# EDGE FLOWS AND TRAVEL TIMES:
# ------------------------------------------------------------
# Edge                 Flow       Travel Time     Capacity Usage
# ------------------------------------------------------------
# Başlangıç1 -> Ara10           4398       97.14           100.0
# Başlangıç2 -> Ara11           2199       53.97           100.0
# Başlangıç3 -> Ara13           2199       64.76           100.0
# Başlangıç3 -> Ara12           2199       24.20           33.3
# Başlangıç3 -> Başlangıç4      10         0.00            0.0
# Başlangıç4 -> Başlangıç3      10         0.00            0.0
# Başlangıç4 -> Başlangıç5      10         0.00            0.0
# Başlangıç5 -> Ara13           4398       113.33          100.0
# Başlangıç5 -> Başlangıç4      10         0.00            0.0
# Başlangıç6 -> Ara14           6597       80.95           100.0
# Başlangıç6 -> Başlangıç7      0          0.00            0.0
# Başlangıç7 -> Başlangıç6      3299       0.00            3.3
# Başlangıç8 -> Ara21           4399       188.94          100.0
# Başlangıç9 -> Ara24           6598       102.56          100.0
# Ara10 -> Ara16           4398       129.52          100.0
# Ara11 -> Ara10           0          77.40           0.0
# Ara11 -> Ara12           0          68.00           0.0
# Ara11 -> Ara17           2199       53.97           100.0
# Ara12 -> Ara18           2199       80.95           100.0
# Ara13 -> Ara14           2200       66.00           33.3
# Ara13 -> Ara19           4398       102.54          100.0
# Ara14 -> Ara15           8797       32.39           100.0
# Ara15 -> Ara20           2200       32.40           50.0
# Ara15 -> Ara35           6597       167.30          100.0
# Ara16 -> Ara28           6598       528.99          100.0
# Ara17 -> Ara16           2199       20.99           50.0
# Ara17 -> Ara18           0          12.00           0.0
# Ara18 -> Ara19           2199       32.99           33.3
# Ara19 -> Ara20           6597       199.68          100.0
# Ara20 -> Ara34           8797       140.34          100.0
# Ara21 -> Ara22           4105       73.43           62.2
# Ara21 -> Ara35           293        18.16           6.7
# Ara22 -> Ara23           3185       47.49           48.3
# Ara22 -> Bit45           921        109.39          41.9
# Ara23 -> Bit46           3185       158.51          72.4
# Ara24 -> Ara25           1611       44.76           73.2
# Ara24 -> Ara36           4987       53.98           75.6
# Ara25 -> Ara26           1611       66.20           36.6
# Ara25 -> Ara37           0          25.20           0.0
# Ara26 -> Ara27           1611       61.63           36.6
# Ara26 -> Ara38           0          25.20           0.0
# Ara27 -> Ara39           1611       36.52           36.6
# Ara28 -> Bit29           3181       103.08          72.3
# Ara28 -> Bit50           3417       99.28           77.7
# Ara32 -> Bit31           1888       48.96           85.8
# Ara32 -> Bit40           1442       50.20           65.5
# Ara33 -> Ara32           3330       23.17           75.7
# Ara33 -> Bit41           1361       57.20           61.9
# Ara34 -> Bit42           4399       134.96          100.0
# Ara34 -> Ara33           4691       126.65          71.1
# Ara35 -> Ara34           293        48.79           4.4
# Ara35 -> Bit44           6598       302.28          100.0
# Ara36 -> Ara37           3278       32.26           49.7
# Ara36 -> Bit47           1709       154.92          77.7
# Ara37 -> Ara38           1079       26.66           49.0
# Ara37 -> Bit48           2199       74.95           100.0
# Ara38 -> Ara39           1079       74.65           49.0
# Ara39 -> Bit49           2690       91.22           61.1
# ------------------------------------------------------------
#
# PATH FLOWS:
# --------------------------------------------------------------------------------
# Source          Target          Path #       Flow       Time
# --------------------------------------------------------------------------------
# Başlangıç1      Bit29               1       2105     858.73
#     Path: Başlangıç1 -> Ara10 -> Ara16 -> Ara28 -> Bit29
# Başlangıç1      Bit50               1       2294     854.93
#     Path: Başlangıç1 -> Ara10 -> Ara16 -> Ara28 -> Bit50
# Başlangıç2      Bit29               2       1076     761.00
#     Path: Başlangıç2 -> Ara11 -> Ara17 -> Ara16 -> Ara28 -> Bit29
# Başlangıç2      Bit50               2       1123     757.19
#     Path: Başlangıç2 -> Ara11 -> Ara17 -> Ara16 -> Ara28 -> Bit50
# Başlangıç3      Bit31               1        308     706.10
#     Path: Başlangıç3 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç3      Bit31               2        439     676.95
#     Path: Başlangıç3 -> Ara12 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç3      Bit31               3        113     534.67
#     Path: Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç3      Bit31               4         14     578.02
#     Path: Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç3      Bit31               5          1     754.67
#     Path: Başlangıç3 -> Başlangıç4 -> Başlangıç5 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç3      Bit31               6          1     583.24
#     Path: Başlangıç3 -> Başlangıç4 -> Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç3      Bit31               7          1     626.60
#     Path: Başlangıç3 -> Başlangıç4 -> Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç3      Bit40               1        236     707.34
#     Path: Başlangıç3 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç3      Bit40               2        306     678.18
#     Path: Başlangıç3 -> Ara12 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç3      Bit40               3        102     535.91
#     Path: Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç3      Bit40               4         14     579.26
#     Path: Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç3      Bit40               5          1     755.91
#     Path: Başlangıç3 -> Başlangıç4 -> Başlangıç5 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç3      Bit40               6          1     584.48
#     Path: Başlangıç3 -> Başlangıç4 -> Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç3      Bit40               7          1     627.83
#     Path: Başlangıç3 -> Başlangıç4 -> Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç3      Bit41               1        222     691.17
#     Path: Başlangıç3 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç3      Bit41               2        283     662.01
#     Path: Başlangıç3 -> Ara12 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç3      Bit41               3         99     519.73
#     Path: Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç3      Bit41               4         14     563.09
#     Path: Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Bit41
# Başlangıç3      Bit41               5          1     739.74
#     Path: Başlangıç3 -> Başlangıç4 -> Başlangıç5 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç3      Bit41               6          1     568.30
#     Path: Başlangıç3 -> Başlangıç4 -> Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç3      Bit41               7          1     611.66
#     Path: Başlangıç3 -> Başlangıç4 -> Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Bit41
# Başlangıç3      Bit42               1        548     642.27
#     Path: Başlangıç3 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Bit42
# Başlangıç3      Bit42               2       1170     613.12
#     Path: Başlangıç3 -> Ara12 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Bit42
# Başlangıç3      Bit42               3        135     470.84
#     Path: Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Bit42
# Başlangıç3      Bit42               4         15     514.20
#     Path: Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Bit42
# Başlangıç3      Bit42               5          1     690.84
#     Path: Başlangıç3 -> Başlangıç4 -> Başlangıç5 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Bit42
# Başlangıç3      Bit42               6          1     519.41
#     Path: Başlangıç3 -> Başlangıç4 -> Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Bit42
# Başlangıç3      Bit42               7          1     562.77
#     Path: Başlangıç3 -> Başlangıç4 -> Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Bit42
# Başlangıç3      Bit44               1        373     632.72
#     Path: Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Bit44
# Başlangıç3      Bit44               2          1     681.29
#     Path: Başlangıç3 -> Başlangıç4 -> Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Bit44
# Başlangıç5      Bit31               1        514     754.67
#     Path: Başlangıç5 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç5      Bit31               2        133     583.24
#     Path: Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç5      Bit31               3         15     626.60
#     Path: Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç5      Bit31               4          1     706.10
#     Path: Başlangıç5 -> Başlangıç4 -> Başlangıç3 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç5      Bit31               5          1     676.95
#     Path: Başlangıç5 -> Başlangıç4 -> Başlangıç3 -> Ara12 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç5      Bit31               6          1     534.67
#     Path: Başlangıç5 -> Başlangıç4 -> Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç5      Bit31               7          1     578.02
#     Path: Başlangıç5 -> Başlangıç4 -> Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç5      Bit40               1        340     755.91
#     Path: Başlangıç5 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç5      Bit40               2        117     584.48
#     Path: Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç5      Bit40               3         14     627.83
#     Path: Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç5      Bit40               4          1     707.34
#     Path: Başlangıç5 -> Başlangıç4 -> Başlangıç3 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç5      Bit40               5          1     678.18
#     Path: Başlangıç5 -> Başlangıç4 -> Başlangıç3 -> Ara12 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç5      Bit40               6          1     535.91
#     Path: Başlangıç5 -> Başlangıç4 -> Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç5      Bit40               7          1     579.26
#     Path: Başlangıç5 -> Başlangıç4 -> Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç5      Bit41               1        312     739.74
#     Path: Başlangıç5 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç5      Bit41               2        114     568.30
#     Path: Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç5      Bit41               3         14     611.66
#     Path: Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Bit41
# Başlangıç5      Bit41               4          1     691.17
#     Path: Başlangıç5 -> Başlangıç4 -> Başlangıç3 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç5      Bit41               5          1     662.01
#     Path: Başlangıç5 -> Başlangıç4 -> Başlangıç3 -> Ara12 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç5      Bit41               6          1     519.73
#     Path: Başlangıç5 -> Başlangıç4 -> Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç5      Bit41               7          1     563.09
#     Path: Başlangıç5 -> Başlangıç4 -> Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Bit41
# Başlangıç5      Bit42               1       1913     690.84
#     Path: Başlangıç5 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Bit42
# Başlangıç5      Bit42               2        164     519.41
#     Path: Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Bit42
# Başlangıç5      Bit42               3         15     562.77
#     Path: Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Bit42
# Başlangıç5      Bit42               4          1     642.27
#     Path: Başlangıç5 -> Başlangıç4 -> Başlangıç3 -> Ara13 -> Ara19 -> Ara20 -> Ara34 -> Bit42
# Başlangıç5      Bit42               5          1     613.12
#     Path: Başlangıç5 -> Başlangıç4 -> Başlangıç3 -> Ara12 -> Ara18 -> Ara19 -> Ara20 -> Ara34 -> Bit42
# Başlangıç5      Bit42               6          1     470.84
#     Path: Başlangıç5 -> Başlangıç4 -> Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Bit42
# Başlangıç5      Bit42               7          1     514.20
#     Path: Başlangıç5 -> Başlangıç4 -> Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Bit42
# Başlangıç5      Bit44               1        724     681.29
#     Path: Başlangıç5 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Bit44
# Başlangıç5      Bit44               2          1     632.72
#     Path: Başlangıç5 -> Başlangıç4 -> Başlangıç3 -> Ara13 -> Ara14 -> Ara15 -> Ara35 -> Bit44
# Başlangıç6      Bit31               1        153     484.86
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç6      Bit31               2         15     528.21
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç6      Bit40               1        133     486.10
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç6      Bit40               2         15     529.45
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç6      Bit41               1        128     469.92
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç6      Bit41               2         14     513.28
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Bit41
# Başlangıç6      Bit42               1        196     421.03
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Bit42
# Başlangıç6      Bit42               2         15     464.39
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Bit42
# Başlangıç6      Bit44               1       2631     582.91
#     Path: Başlangıç6 -> Ara14 -> Ara15 -> Ara35 -> Bit44
# Başlangıç7      Bit31               1        153     484.86
#     Path: Başlangıç7 -> Başlangıç6 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç7      Bit31               2         15     528.21
#     Path: Başlangıç7 -> Başlangıç6 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç7      Bit40               1        133     486.10
#     Path: Başlangıç7 -> Başlangıç6 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç7      Bit40               2         15     529.45
#     Path: Başlangıç7 -> Başlangıç6 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç7      Bit41               1        128     469.92
#     Path: Başlangıç7 -> Başlangıç6 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Ara33 -> Bit41
# Başlangıç7      Bit41               2         14     513.28
#     Path: Başlangıç7 -> Başlangıç6 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Ara33 -> Bit41
# Başlangıç7      Bit42               1        195     421.03
#     Path: Başlangıç7 -> Başlangıç6 -> Ara14 -> Ara15 -> Ara20 -> Ara34 -> Bit42
# Başlangıç7      Bit42               2         15     464.39
#     Path: Başlangıç7 -> Başlangıç6 -> Ara14 -> Ara15 -> Ara35 -> Ara34 -> Bit42
# Başlangıç7      Bit44               1       2631     582.91
#     Path: Başlangıç7 -> Başlangıç6 -> Ara14 -> Ara15 -> Ara35 -> Bit44
# Başlangıç8      Bit31               1         14     454.68
#     Path: Başlangıç8 -> Ara21 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit31
# Başlangıç8      Bit40               1         14     455.92
#     Path: Başlangıç8 -> Ara21 -> Ara35 -> Ara34 -> Ara33 -> Ara32 -> Bit40
# Başlangıç8      Bit41               1         14     439.75
#     Path: Başlangıç8 -> Ara21 -> Ara35 -> Ara34 -> Ara33 -> Bit41
# Başlangıç8      Bit42               1         14     390.85
#     Path: Başlangıç8 -> Ara21 -> Ara35 -> Ara34 -> Bit42
# Başlangıç8      Bit44               1        238     509.38
#     Path: Başlangıç8 -> Ara21 -> Ara35 -> Bit44
# Başlangıç8      Bit45               1        921     371.77
#     Path: Başlangıç8 -> Ara21 -> Ara22 -> Bit45
# Başlangıç8      Bit46               1       3185     468.38
#     Path: Başlangıç8 -> Ara21 -> Ara22 -> Ara23 -> Bit46
# Başlangıç9      Bit47               1       1709     311.46
#     Path: Başlangıç9 -> Ara24 -> Ara36 -> Bit47
# Başlangıç9      Bit48               2       2199     263.74
#     Path: Başlangıç9 -> Ara24 -> Ara36 -> Ara37 -> Bit48
# Başlangıç9      Bit49               1       1611     402.89
#     Path: Başlangıç9 -> Ara24 -> Ara25 -> Ara26 -> Ara27 -> Ara39 -> Bit49
# Başlangıç9      Bit49               2       1079     381.32
#     Path: Başlangıç9 -> Ara24 -> Ara36 -> Ara37 -> Ara38 -> Ara39 -> Bit49
#
# PATH TIME SUMMARY:
# Minimum Path Time: 263.74
# Maximum Path Time: 858.73
# Flow-Weighted Average Path Time: 579.24
#
# ===== Stage 1 ANALYSIS =====
# Total Flow Amount: 161458
# Average Travel Time: 80.02
# Highest Capacity Utilization: 100.0% (Edge: ('Başlangıç8', 'Ara21'))
# Total Travel Time for All Edges: 19108159.32
# \STAGE 2
# -------------------------
#
# ========= PASSENGER DISTRIBUTION AT START POINTS =========
# --------------------------------------------------
# Start Point          Passenger Count
# --------------------------------------------------
# Başlangıç51                    4,716
# Başlangıç52                    4,714
# Başlangıç56                    4,714
# Başlangıç57                    4,714
# Başlangıç67                    4,714
# Başlangıç68                    4,714
# Başlangıç70                    4,714
# --------------------------------------------------
# TOTAL                         33,000
# --------------------------------------------------
# Ipopt 3.14.17: max_iter=10000
# tol=1e-06
# print_level=4
#
# ==> Warning: Treating 0 binary and 193 integer variables as continuous.
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# Total number of variables............................:      227
#                      variables with only lower bounds:      227
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       73
# Total number of inequality constraints...............:       66
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       66
#
#
# Number of Iterations....: 10000
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.0152826707131934e+05    4.0152826707131934e+05
# Dual infeasibility......:   4.5683513722636999e+04    4.5683513722636999e+04
# Constraint violation....:   5.2621629423604645e+01    5.2621629423604645e+01
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   1.0102355186371268e+05    1.0102355186371268e+05
# Overall NLP error.......:   1.1478929854063477e+04    1.0102355186371268e+05
#
#
# Number of objective function evaluations             = 121284
# Number of objective gradient evaluations             = 9952
# Number of equality constraint evaluations            = 121284
# Number of inequality constraint evaluations          = 121284
# Number of equality constraint Jacobian evaluations   = 10002
# Number of inequality constraint Jacobian evaluations = 10002
# Number of Lagrangian Hessian evaluations             = 10000
# Total seconds in IPOPT                               = 50.623
#
# EXIT: Maximum Number of Iterations Exceeded.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: maxIterations
#     - message from solver: Ipopt 3.14.17\x3a Maximum Number of Iterations
#       Exceeded.
#
# ==================== RESULTS ====================
# Objective Value: 401528.27
#
# EDGE FLOWS AND TRAVEL TIMES:
# ------------------------------------------------------------
# Edge                 Flow       Travel Time     Capacity Usage
# ------------------------------------------------------------
# Başlangıç51 -> Başlangıç52     3212       0.00            0.3
# Başlangıç51 -> Ara64           2200       270.00          100.0
# Başlangıç52 -> Başlangıç51     748        0.00            0.1
# Başlangıç52 -> Başlangıç56     2761       0.00            0.3
# Başlangıç52 -> Ara64           4366       106.89          99.2
# Başlangıç56 -> Başlangıç57     3419       0.00            0.3
# Başlangıç57 -> Başlangıç56     2499       0.00            0.2
# Başlangıç56 -> Ara65           6505       79.46           98.6
# Başlangıç57 -> Başlangıç67     4796       0.00            0.5
# Başlangıç57 -> Başlangıç56     2499       0.00            0.2
# Başlangıç57 -> Ara66           4312       99.89           98.0
# Başlangıç67 -> Başlangıç57     3519       0.00            0.4
# Başlangıç67 -> Başlangıç68     4811       0.00            0.5
# Başlangıç67 -> Ara76           6563       150.07          99.4
# Başlangıç68 -> Başlangıç67     5414       0.00            0.5
# Başlangıç68 -> Başlangıç70     5125       0.00            0.5
# Başlangıç68 -> Ara77           2200       205.20          100.0
# Başlangıç70 -> Başlangıç68     3244       0.00            0.3
# Başlangıç70 -> Ara78           6561       214.30          99.4
# Ara64 -> Ara65           2647       148.94          60.2
# Ara64 -> Ara74           3920       232.87          89.1
# Ara65 -> Ara66           4413       96.90           33.4
# Ara65 -> Ara72           4739       29.25           71.8
# Ara66 -> Ara73           8726       69.42           99.2
# Ara72 -> Ara73           2136       228.52          97.1
# Ara72 -> Ara74           2602       24.47           59.1
# Ara73 -> Ara75           10862      69.03           98.7
# Ara74 -> Ara75           6522       233.88          98.8
# Ara75 -> Ara76           6453       152.00          97.8
# Ara75 -> Bit79           10931      117.81          99.4
# Ara76 -> Ara77           2121       210.99          96.4
# Ara76 -> Bit80           10896      165.30          99.1
# Ara77 -> Ara78           4321       94.89           98.2
# Ara78 -> Bit81           10882      234.22          98.9
# ------------------------------------------------------------
#
# PATH FLOWS:
# --------------------------------------------------------------------------------
# Source          Target          Path #       Flow       Time
# --------------------------------------------------------------------------------
# Başlangıç51     Bit79               1        522     854.56
#     Path: Başlangıç51 -> Ara64 -> Ara74 -> Ara75 -> Bit79
# Başlangıç51     Bit79               2        868     691.45
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara74 -> Ara75 -> Bit79
# Başlangıç51     Bit79               3        150     772.10
#     Path: Başlangıç51 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç51     Bit79               4         85     863.55
#     Path: Başlangıç51 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç51     Bit79               5        104     824.35
#     Path: Başlangıç51 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç51     Bit79               6        123     356.15
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç51     Bit79               7        155     608.99
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç51     Bit79               8        148     432.62
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç51     Bit79               9         89     700.44
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç51     Bit79              10         87     524.07
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç51     Bit79              11        109     661.24
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç51     Bit79              12        107     484.86
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç51     Bit80               1        196    1054.05
#     Path: Başlangıç51 -> Ara64 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80               2        124     315.37
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Ara76 -> Bit80
# Başlangıç51     Bit80               3        226     890.94
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80               4         98     971.59
#     Path: Başlangıç51 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80               5         65    1063.04
#     Path: Başlangıç51 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80               6         75    1023.84
#     Path: Başlangıç51 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80               7        100     632.11
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80               8         88     555.64
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80               9        105     808.48
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80              10         68     723.56
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80              11         69     899.93
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80              12         79     684.36
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit80              13         81     860.73
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç51     Bit81               1         49    1428.85
#     Path: Başlangıç51 -> Ara64 -> Ara74 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç51     Bit81               2        128     448.52
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Başlangıç68 -> Başlangıç70 -> Ara78 -> Bit81
# Başlangıç51     Bit81               3         52    1265.74
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara74 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç51     Bit81               4         43     690.18
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç51     Bit81               5        103     534.31
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Başlangıç68 -> Ara77 -> Ara78 -> Bit81
# Başlangıç51     Bit81               6         39    1346.40
#     Path: Başlangıç51 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç51     Bit81               7         33    1437.84
#     Path: Başlangıç51 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç51     Bit81               8         35    1398.64
#     Path: Başlangıç51 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç51     Bit81               9         40    1006.92
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç51     Bit81              10         38     930.45
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç51     Bit81              11         40    1183.29
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç51     Bit81              12         34    1098.36
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç51     Bit81              13         34    1274.73
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç51     Bit81              14         36    1059.16
#     Path: Başlangıç51 -> Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç51     Bit81              15         36    1235.53
#     Path: Başlangıç51 -> Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç52     Bit79               1       1411     691.45
#     Path: Başlangıç52 -> Ara64 -> Ara74 -> Ara75 -> Bit79
# Başlangıç52     Bit79               2        145     854.56
#     Path: Başlangıç52 -> Başlangıç51 -> Ara64 -> Ara74 -> Ara75 -> Bit79
# Başlangıç52     Bit79               3        182     608.99
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç52     Bit79               4        130     356.15
#     Path: Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç52     Bit79               5         95     700.44
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç52     Bit79               6        160     432.62
#     Path: Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç52     Bit79               7        119     661.24
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç52     Bit79               8         92     524.07
#     Path: Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç52     Bit79               9        113     484.86
#     Path: Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç52     Bit79              10         81     772.10
#     Path: Başlangıç52 -> Başlangıç51 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç52     Bit79              11         59     863.55
#     Path: Başlangıç52 -> Başlangıç51 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç52     Bit79              12         67     824.35
#     Path: Başlangıç52 -> Başlangıç51 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç52     Bit80               1        131     315.37
#     Path: Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Ara76 -> Bit80
# Başlangıç52     Bit80               2        259     890.94
#     Path: Başlangıç52 -> Ara64 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80               3         98    1054.05
#     Path: Başlangıç52 -> Başlangıç51 -> Ara64 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80               4        105     632.11
#     Path: Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80               5         91     555.64
#     Path: Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80               6        117     808.48
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80               7         70     723.56
#     Path: Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80               8         71     899.93
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80               9         82     684.36
#     Path: Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80              10         84     860.73
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80              11         64     971.59
#     Path: Başlangıç52 -> Başlangıç51 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80              12         49    1063.04
#     Path: Başlangıç52 -> Başlangıç51 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit80              13         55    1023.84
#     Path: Başlangıç52 -> Başlangıç51 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç52     Bit81               1        136     448.52
#     Path: Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Başlangıç68 -> Başlangıç70 -> Ara78 -> Bit81
# Başlangıç52     Bit81               2         53    1265.74
#     Path: Başlangıç52 -> Ara64 -> Ara74 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç52     Bit81               3         44     690.18
#     Path: Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç52     Bit81               4        108     534.31
#     Path: Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Başlangıç68 -> Ara77 -> Ara78 -> Bit81
# Başlangıç52     Bit81               5         40    1428.85
#     Path: Başlangıç52 -> Başlangıç51 -> Ara64 -> Ara74 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç52     Bit81               6         41    1006.92
#     Path: Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç52     Bit81               7         39     930.45
#     Path: Başlangıç52 -> Başlangıç56 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç52     Bit81               8         41    1183.29
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç52     Bit81               9         34    1098.36
#     Path: Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç52     Bit81              10         34    1274.73
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç52     Bit81              11         37    1059.16
#     Path: Başlangıç52 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç52     Bit81              12         37    1235.53
#     Path: Başlangıç52 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç52     Bit81              13         33    1346.40
#     Path: Başlangıç52 -> Başlangıç51 -> Ara64 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç52     Bit81              14         28    1437.84
#     Path: Başlangıç52 -> Başlangıç51 -> Ara64 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç52     Bit81              15         30    1398.64
#     Path: Başlangıç52 -> Başlangıç51 -> Ara64 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç56     Bit79               1        498     356.15
#     Path: Başlangıç56 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç56     Bit79               2       1405     432.62
#     Path: Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç56     Bit79               3        193     524.07
#     Path: Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç56     Bit79               4        315     484.86
#     Path: Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç56     Bit80               1        496     315.37
#     Path: Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Ara76 -> Bit80
# Başlangıç56     Bit80               2        251     632.11
#     Path: Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç56     Bit80               3        188     555.64
#     Path: Başlangıç56 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç56     Bit80               4        115     723.56
#     Path: Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç56     Bit80               5        152     684.36
#     Path: Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç56     Bit81               1        527     448.52
#     Path: Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Başlangıç68 -> Başlangıç70 -> Ara78 -> Bit81
# Başlangıç56     Bit81               2         59     690.18
#     Path: Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç56     Bit81               3        272     534.31
#     Path: Başlangıç56 -> Başlangıç57 -> Başlangıç67 -> Başlangıç68 -> Ara77 -> Ara78 -> Bit81
# Başlangıç56     Bit81               4         53    1006.92
#     Path: Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç56     Bit81               5         49     930.45
#     Path: Başlangıç56 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç56     Bit81               6         42    1098.36
#     Path: Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç56     Bit81               7         46    1059.16
#     Path: Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç57     Bit79               1       1044     356.15
#     Path: Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç57     Bit79               2        151     432.62
#     Path: Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç57     Bit79               3         88     524.07
#     Path: Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç57     Bit79               4        108     484.86
#     Path: Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç57     Bit80               1       1033     315.37
#     Path: Başlangıç57 -> Başlangıç67 -> Ara76 -> Bit80
# Başlangıç57     Bit80               2        247     555.64
#     Path: Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç57     Bit80               3        100     632.11
#     Path: Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç57     Bit80               4         68     723.56
#     Path: Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç57     Bit80               5         79     684.36
#     Path: Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç57     Bit81               1       1148     448.52
#     Path: Başlangıç57 -> Başlangıç67 -> Başlangıç68 -> Başlangıç70 -> Ara78 -> Bit81
# Başlangıç57     Bit81               2         63     690.18
#     Path: Başlangıç57 -> Başlangıç67 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç57     Bit81               3        380     534.31
#     Path: Başlangıç57 -> Başlangıç67 -> Başlangıç68 -> Ara77 -> Ara78 -> Bit81
# Başlangıç57     Bit81               4         52     930.45
#     Path: Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç57     Bit81               5         40    1006.92
#     Path: Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç57     Bit81               6         34    1098.36
#     Path: Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç57     Bit81               7         36    1059.16
#     Path: Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç67     Bit79               1        357     356.15
#     Path: Başlangıç67 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç67     Bit79               2        116     432.62
#     Path: Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç67     Bit79               3         75     524.07
#     Path: Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç67     Bit79               4         89     484.86
#     Path: Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç67     Bit80               1       1444     315.37
#     Path: Başlangıç67 -> Ara76 -> Bit80
# Başlangıç67     Bit80               2        165     555.64
#     Path: Başlangıç67 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç67     Bit80               3         84     632.11
#     Path: Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç67     Bit80               4         60     723.56
#     Path: Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç67     Bit80               5         69     684.36
#     Path: Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç67     Bit81               1       1586     448.52
#     Path: Başlangıç67 -> Başlangıç68 -> Başlangıç70 -> Ara78 -> Bit81
# Başlangıç67     Bit81               2         64     690.18
#     Path: Başlangıç67 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç67     Bit81               3        423     534.31
#     Path: Başlangıç67 -> Başlangıç68 -> Ara77 -> Ara78 -> Bit81
# Başlangıç67     Bit81               4         48     930.45
#     Path: Başlangıç67 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç67     Bit81               5         37    1006.92
#     Path: Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç67     Bit81               6         32    1098.36
#     Path: Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç67     Bit81               7         34    1059.16
#     Path: Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç68     Bit79               1        356     356.15
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç68     Bit79               2        116     432.62
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç68     Bit79               3         75     524.07
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç68     Bit79               4         89     484.86
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç68     Bit80               1       1376     315.37
#     Path: Başlangıç68 -> Başlangıç67 -> Ara76 -> Bit80
# Başlangıç68     Bit80               2        165     555.64
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç68     Bit80               3         84     632.11
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç68     Bit80               4         60     723.56
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç68     Bit80               5         69     684.36
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç68     Bit81               1       1599     448.52
#     Path: Başlangıç68 -> Başlangıç70 -> Ara78 -> Bit81
# Başlangıç68     Bit81               2        479     534.31
#     Path: Başlangıç68 -> Ara77 -> Ara78 -> Bit81
# Başlangıç68     Bit81               3         64     690.18
#     Path: Başlangıç68 -> Başlangıç67 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç68     Bit81               4         48     930.45
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç68     Bit81               5         37    1006.92
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç68     Bit81               6         32    1098.36
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç68     Bit81               7         34    1059.16
#     Path: Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç70     Bit79               1        369     356.15
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç70     Bit79               2        118     432.62
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Bit79
# Başlangıç70     Bit79               3         76     524.07
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Bit79
# Başlangıç70     Bit79               4         90     484.86
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Bit79
# Başlangıç70     Bit80               1       1557     315.37
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Ara76 -> Bit80
# Başlangıç70     Bit80               2        167     555.64
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç70     Bit80               3         86     632.11
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç70     Bit80               4         61     723.56
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Bit80
# Başlangıç70     Bit80               5         70     684.36
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Bit80
# Başlangıç70     Bit81               1       1437     448.52
#     Path: Başlangıç70 -> Ara78 -> Bit81
# Başlangıç70     Bit81               2        436     534.31
#     Path: Başlangıç70 -> Başlangıç68 -> Ara77 -> Ara78 -> Bit81
# Başlangıç70     Bit81               3         64     690.18
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç70     Bit81               4         48     930.45
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç70     Bit81               5         37    1006.92
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara66 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç70     Bit81               6         32    1098.36
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara73 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
# Başlangıç70     Bit81               7         34    1059.16
#     Path: Başlangıç70 -> Başlangıç68 -> Başlangıç67 -> Başlangıç57 -> Başlangıç56 -> Ara65 -> Ara72 -> Ara74 -> Ara75 -> Ara76 -> Ara77 -> Ara78 -> Bit81
#
# PATH TIME SUMMARY:
# Minimum Path Time: 315.37
# Maximum Path Time: 1437.84
# Flow-Weighted Average Path Time: 539.10
#
# ===== Stage 2 ANALYSIS =====
# Total Flow Amount: 166925
# Average Travel Time: 95.13
# Highest Capacity Utilization: 100.0% (Edge: ('Başlangıç51', 'Ara64'))
# Total Travel Time for All Edges: 17632810.73

# %% [markdown]
# ## Test Case 3

# %%
edges = [
    ("Başlangıç1", "Ara1"),
    ("Başlangıç1", "Ara2"),
    ("Ara1", "Ara3"),
    ("Ara1", "Ara4"),
    ("Ara2", "Ara4"),
    ("Ara3", "Bit1"),
    ("Ara4", "Bit2")
]

travel_time = {
    ("Başlangıç1", "Ara1"): 100.0,
    ("Başlangıç1", "Ara2"): 120.0,
    ("Ara1", "Ara3"): 50.0,
    ("Ara1", "Ara4"): 60.0,
    ("Ara2", "Ara4"): 40.0,
    ("Ara3", "Bit1"): 80.0,
    ("Ara4", "Bit2"): 70.0
}
capacity = {
    ("Başlangıç1", "Ara1"): 10000,
    ("Başlangıç1", "Ara2"): 12000,
    ("Ara1", "Ara3"): 8000,
    ("Ara1", "Ara4"): 8000,
    ("Ara2", "Ara4"): 6000,
    ("Ara3", "Bit1"): 7000,
    ("Ara4", "Bit2"): 7000
}
passengers = {
    "Başlangıç1": 10000,
    "Ara1": 0,
    "Ara2": 0,
    "Ara3": 0,
    "Ara4": 0,
    "Bit1": 0,
    "Bit2": 0
}

# %%
new_edges = [
    ('Başlangıç1', 'Başlangıç2'), ('Başlangıç1', 'Ara1'), ('Başlangıç1', 'Ara2'), 
    ('Başlangıç2', 'Başlangıç1'), ('Başlangıç2', 'Ara3'),
    ('Ara2', 'Ara3'), ('Ara2', 'Ara1'),
    ('Ara1', 'Bit1'), ('Ara3', 'Bit2'),
]
new_travel_time = {
    ('Başlangıç1', 'Başlangıç2'):0, ('Başlangıç1', 'Ara1'):12.4, ('Başlangıç1', 'Ara2'):120, 
    ('Başlangıç2', 'Başlangıç1'):0, ('Başlangıç2', 'Ara3'):12.4,
    ('Ara2', 'Ara3'):60, ('Ara2', 'Ara1'):30,
    ('Ara1', 'Bit1'):30, ('Ara3', 'Bit2'):40,
}
new_capacity = {
    ('Başlangıç1', 'Başlangıç2'):100000, ('Başlangıç1', 'Ara1'):1000, ('Başlangıç1', 'Ara2'):8000, 
    ('Başlangıç2', 'Başlangıç1'):100000, ('Başlangıç2', 'Ara3'):1000,
    ('Ara2', 'Ara3'):4000, ('Ara2', 'Ara1'):6000,
    ('Ara1', 'Bit1'):6000, ('Ara3', 'Bit2'):4000,
}
baslangic_noktalari = ['Başlangıç1', 'Başlangıç2']
new_passengers = {}

# %%
run_two_stage_optimization()
# Out:
# STAGE 1 -
# -------------------------
#
# ========= BAŞLANGIÇ NOKTALARI YOLCU DAĞILIMI =========
# --------------------------------------------------
# Başlangıç Noktası       Yolcu Sayısı
# --------------------------------------------------
# Başlangıç1                    10,000
# --------------------------------------------------
# TOPLAM                        10,000
# --------------------------------------------------
# Ipopt 3.14.17: max_iter=10000
# tol=1e-06
# print_level=4
#
# ==> Warning: Treating 0 binary and 10 integer variables as continuous.
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# Total number of variables............................:       18
#                      variables with only lower bounds:       18
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       15
# Total number of inequality constraints...............:       14
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       14
#
#
# Number of Iterations....: 37
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.6829267861358588e+01    4.6829267861358588e+01
# Dual infeasibility......:   9.2872571542156639e-11    9.2872571542156639e-11
# Constraint violation....:   7.5030911261819710e-08    7.5030911261819710e-08
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.2102312602029653e-08    9.2102312602029653e-08
# Overall NLP error.......:   9.2102312602029653e-08    9.2102312602029653e-08
#
#
# Number of objective function evaluations             = 43
# Number of objective gradient evaluations             = 18
# Number of equality constraint evaluations            = 43
# Number of inequality constraint evaluations          = 43
# Number of equality constraint Jacobian evaluations   = 39
# Number of inequality constraint Jacobian evaluations = 39
# Number of Lagrangian Hessian evaluations             = 37
# Total seconds in IPOPT                               = 0.045
#
# EXIT: Optimal Solution Found.
#
# ==================== RESULTS ====================
# Objective Value: 46.83
#
# EDGE FLOWS AND TRAVEL TIMES:
# ------------------------------------------------------------
# Edge                 Flow       Travel Time     Capacity Usage
# ------------------------------------------------------------
# Başlangıç1 -> Ara1            7695       218.43          77.0
# Başlangıç1 -> Ara2            2305       128.86          19.2
# Ara1 -> Ara3            3000       64.06           37.5
# Ara1 -> Ara4            4695       101.33          58.7
# Ara2 -> Ara4            2305       51.81           38.4
# Ara3 -> Bit1            3000       109.39          42.9
# Ara4 -> Bit2            7000       210.00          100.0
# ------------------------------------------------------------
#
# PATH FLOWS:
# --------------------------------------------------------------------------------
# Source          Target          Path #       Flow       Time
# --------------------------------------------------------------------------------
# Başlangıç1      Bit1                1       3000     391.88
#     Path: Başlangıç1 -> Ara1 -> Ara3 -> Bit1
# Başlangıç1      Bit2                1       4695     529.76
#     Path: Başlangıç1 -> Ara1 -> Ara4 -> Bit2
# Başlangıç1      Bit2                2       2305     390.66
#     Path: Başlangıç1 -> Ara2 -> Ara4 -> Bit2
#
# PATH TIME SUMMARY:
# Minimum Path Time: 390.66
# Maximum Path Time: 529.76
# Flow-Weighted Average Path Time: 456.33
#
# ===== Stage 1 ANALYZE =====
# Toplam Akış Miktarı: 30000
# Ortalama Seyahat Süresi: 126.27
# En Yüksek Kapasite Kullanımı: 100.0% (Kenar: ('Ara4', 'Bit2'))
# Tüm Kenarlar İçin Toplam Seyahat Süresi: 4563312.09
# \STAGE 2
# -------------------------
#
# ========= BAŞLANGIÇ NOKTALARI YOLCU DAĞILIMI =========
# --------------------------------------------------
# Başlangıç Noktası       Yolcu Sayısı
# --------------------------------------------------
# Başlangıç1                     5,000
# Başlangıç2                     5,000
# --------------------------------------------------
# TOPLAM                        10,000
# --------------------------------------------------
# Ipopt 3.14.17: max_iter=10000
# tol=1e-06
# print_level=4
#
# ==> Warning: Treating 0 binary and 17 integer variables as continuous.
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# Total number of variables............................:       27
#                      variables with only lower bounds:       27
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       20
# Total number of inequality constraints...............:       18
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       18
#
#
# Number of Iterations....: 10000
#
#                                    (scaled)                 (unscaled)
# Objective...............:   8.9105318862620792e+09    8.9105318862620792e+09
# Dual infeasibility......:   6.4725611774719814e+12    6.4725611774719814e+12
# Constraint violation....:   4.0546450022055831e+00    4.0546450022055831e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   4.5845190772749431e+00    4.5845190772749431e+00
# Overall NLP error.......:   4.0546450022055831e+00    6.4725611774719814e+12
#
#
# Number of objective function evaluations             = 104494
# Number of objective gradient evaluations             = 9965
# Number of equality constraint evaluations            = 104509
# Number of inequality constraint evaluations          = 104509
# Number of equality constraint Jacobian evaluations   = 10002
# Number of inequality constraint Jacobian evaluations = 10002
# Number of Lagrangian Hessian evaluations             = 10000
# Total seconds in IPOPT                               = 19.948
#
# EXIT: Maximum Number of Iterations Exceeded.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: maxIterations
#     - message from solver: Ipopt 3.14.17\x3a Maximum Number of Iterations
#       Exceeded.
#
# ==================== RESULTS ====================
# Objective Value: 8910531886.26
#
# EDGE FLOWS AND TRAVEL TIMES:
# ------------------------------------------------------------
# Edge                 Flow       Travel Time     Capacity Usage
# ------------------------------------------------------------
# Başlangıç1 -> Başlangıç2      0          0.00            0.0
# Başlangıç1 -> Ara1            1000       37.20           100.0
# Başlangıç1 -> Ara2            8000       360.00          100.0
# Başlangıç2 -> Başlangıç1      4000       0.00            4.0
# Başlangıç2 -> Ara3            1000       37.20           100.0
# Ara2 -> Ara3            3000       127.50          75.0
# Ara2 -> Ara1            5000       71.67           83.3
# Ara1 -> Bit1            6000       90.00           100.0
# Ara3 -> Bit2            4000       120.00          100.0
# ------------------------------------------------------------
#
# PATH FLOWS:
# --------------------------------------------------------------------------------
# Source          Target          Path #       Flow       Time
# --------------------------------------------------------------------------------
# Başlangıç1      Bit1                1        515     127.20
#     Path: Başlangıç1 -> Ara1 -> Bit1
# Başlangıç1      Bit1                2       2856     521.67
#     Path: Başlangıç1 -> Ara2 -> Ara1 -> Bit1
# Başlangıç1      Bit2                2       1630     607.50
#     Path: Başlangıç1 -> Ara2 -> Ara3 -> Bit2
# Başlangıç2      Bit1                1        485     127.20
#     Path: Başlangıç2 -> Başlangıç1 -> Ara1 -> Bit1
# Başlangıç2      Bit1                2       2144     521.67
#     Path: Başlangıç2 -> Başlangıç1 -> Ara2 -> Ara1 -> Bit1
# Başlangıç2      Bit2                1       1000     157.20
#     Path: Başlangıç2 -> Ara3 -> Bit2
# Başlangıç2      Bit2                2       1370     607.50
#     Path: Başlangıç2 -> Başlangıç1 -> Ara2 -> Ara3 -> Bit2
#
# PATH TIME SUMMARY:
# Minimum Path Time: 127.20
# Maximum Path Time: 607.50
# Flow-Weighted Average Path Time: 471.52
#
# ===== Stage 2 ANALYZE =====
# Toplam Akış Miktarı: 32000
# Ortalama Seyahat Süresi: 93.73
# En Yüksek Kapasite Kullanımı: 100.0% (Kenar: ('Başlangıç1', 'Ara1'))
# Tüm Kenarlar İçin Toplam Seyahat Süresi: 4715233.33
